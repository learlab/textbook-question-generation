# %%
from collections import defaultdict

from tqdm.auto import tqdm
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../../data/itell-question-data-w-o3-scores.csv")
df
# Out:
#                                         id  \
# 0     38f590ee-1964-4a7c-9625-53b53cb8a9f0
# 1     95784937-f565-4450-bfad-babc2399d667
# 2     88c0f433-7fdb-48ad-9898-a08d861635e1
# 3     53c99817-a318-45e5-a918-6b2e7dd4e8d1
# 4     9f3eeb88-7254-402f-b025-b3c0298e2a64
# ...                                    ...
# 1423                                  2257
# 1424                                  1515
# 1425                                  2458
# 1426                                  2794
# 1427                                   232
#
#                                                response  score condition  \
# 0                                              learning      0       NaN
# 1                                                answer      0       NaN
# 2     human observers made live annotations regardin...      0       NaN
# 3     Recorded data from student while doing help ba...      0       NaN
# 4                                     analyzing context      0       NaN
# ...                                                 ...    ...       ...
# 1423  Slow technological progress, natural disasters...      2    stairs
# 1424  Economic conditions before 1870 were sluggish ...      2    stairs
# 1425                      economic conditions were slow      2    stairs
# 1426  Before 1870, economic conditions were relative...      2    stairs
# 1427  The purpose of a "do . . . while " loop in Jav...      2    stairs
#
#                          user_id  \
# 0      clu91tykw0002l00fz3o1vfsh
# 1      cluc0hclp0000ju0flnuywkrr
# 2      clu7cooq9000kjt0fbxh29vfy
# 3      clucz38h40005jv0fhc5vjpfp
# 4      clu8uwkw20000jz0f4yyg6c1d
# ...                          ...
# 1423  pkwlvvzebu2ppqvjop66x5hequ
# 1424  mx25ylobcck2yg2xkiv4srpfh4
# 1425  kwj3wlbqwnfecwceaxe2noulju
# 1426  dggh43s5cosnmyxo57zex3cucy
# 1427  c35eotu6a3guavdkekjwe3346i
#
#                                               page_slug  \
# 0                                             emotional
# 1                                             emotional
# 2                                             emotional
# 3                                             emotional
# 4                                             emotional
# ...                                                 ...
# 1423  7-1-the-relatively-recent-arrival-of-economic-...
# 1424  7-1-the-relatively-recent-arrival-of-economic-...
# 1425  7-1-the-relatively-recent-arrival-of-economic-...
# 1426  7-1-the-relatively-recent-arrival-of-economic-...
# 1427                                2-program-structure
#
#                                              chunk_slug  \
# 0     01-Affect-Detection-from-Student-Activity-Data...
# 1     01-Affect-Detection-from-Student-Activity-Data...
# 2     01-Affect-Detection-from-Student-Activity-Data...
# 3     01-Affect-Detection-from-Student-Activity-Data...
# 4     01-Affect-Detection-from-Student-Activity-Data...
# ...                                                 ...
# 1423                           learning-objectives-700t
# 1424                           learning-objectives-700t
# 1425                           learning-objectives-700t
# 1426                           learning-objectives-700t
# 1427                            while-and-do-Loops-789t
#
#                             created_at          volume_slug  \
# 0              2024-04-15 19:57:38.656              cornell
# 1               2024-05-05 20:29:28.14              cornell
# 2              2024-04-15 19:03:37.985              cornell
# 3              2024-03-30 01:56:12.488              cornell
# 4              2024-05-03 20:56:52.298              cornell
# ...                                ...                  ...
# 1423  2024-08-15 22:19:30.781007+00:00             cttc-poe
# 1424  2024-08-12 18:03:45.775565+00:00             cttc-poe
# 1425  2024-08-15 23:28:39.503359+00:00             cttc-poe
# 1426  2024-08-16 20:43:33.145129+00:00             cttc-poe
# 1427      2024-09-01 20:34:24.20905+00  eloquent-javascript
#
#                         volume_title  \
# 0     Handbook of Learning Analytics
# 1     Handbook of Learning Analytics
# 2     Handbook of Learning Analytics
# 3     Handbook of Learning Analytics
# 4     Handbook of Learning Analytics
# ...                              ...
# 1423    Principles of Macroeconomics
# 1424    Principles of Macroeconomics
# 1425    Principles of Macroeconomics
# 1426    Principles of Macroeconomics
# 1427             Eloquent JavaScript
#
#                                              page_title  \
# 0                          Emotional Learning Analytics
# 1                          Emotional Learning Analytics
# 2                          Emotional Learning Analytics
# 3                          Emotional Learning Analytics
# 4                          Emotional Learning Analytics
# ...                                                 ...
# 1423  7.1 The Relatively Recent Arrival of Economic ...
# 1424  7.1 The Relatively Recent Arrival of Economic ...
# 1425  7.1 The Relatively Recent Arrival of Economic ...
# 1426  7.1 The Relatively Recent Arrival of Economic ...
# 1427                               2. Program Structure
#
#                                          chunk_header  \
# 0     0.1 Affect Detection from Student Activity Data
# 1     0.1 Affect Detection from Student Activity Data
# 2     0.1 Affect Detection from Student Activity Data
# 3     0.1 Affect Detection from Student Activity Data
# 4     0.1 Affect Detection from Student Activity Data
# ...                                               ...
# 1423                              learning objectives
# 1424                              learning objectives
# 1425                              learning objectives
# 1426                              learning objectives
# 1427                               while and do Loops
#
#                                              chunk_text  \
# 0     Affective states cannot be directly measured b...
# 1     Affective states cannot be directly measured b...
# 2     Affective states cannot be directly measured b...
# 3     Affective states cannot be directly measured b...
# 4     Affective states cannot be directly measured b...
# ...                                                 ...
# 1423  Let’s begin with a brief overview of spectacul...
# 1424  Let’s begin with a brief overview of spectacul...
# 1425  Let’s begin with a brief overview of spectacul...
# 1426  Let’s begin with a brief overview of spectacul...
# 1427  Consider a program that outputs all even numbe...
#
#                                                question  \
# 0     What approach was used to infer affect by anal...
# 1     What approach was used to infer affect by anal...
# 2     What approach was used to infer affect by anal...
# 3     What approach was used to infer affect by anal...
# 4     What approach was used to infer affect by anal...
# ...                                                 ...
# 1423    What were economic conditions like before 1870?
# 1424    What were economic conditions like before 1870?
# 1425    What were economic conditions like before 1870?
# 1426    What were economic conditions like before 1870?
# 1427    What is the purpose of a do loop in JavaScript?
#
#                                                  answer  o3_mini_score
# 0     The interaction-based, log-file based, or sens...              1
# 1     The interaction-based, log-file based, or sens...              1
# 2     The interaction-based, log-file based, or sens...              2
# 3     The interaction-based, log-file based, or sens...              2
# 4     The interaction-based, log-file based, or sens...              2
# ...                                                 ...            ...
# 1423  Economic conditions before 1870 were marked by...              4
# 1424  Economic conditions before 1870 were marked by...              2
# 1425  Economic conditions before 1870 were marked by...              2
# 1426  Economic conditions before 1870 were marked by...              2
# 1427  A do loop always executes its body at least on...              4
#
# [1428 rows x 16 columns]

# %%
def assign_questions_to_annotators(df, group_column='chunk_slug', responses_per_annotator=30):
    """
    Assign questions to annotators using a greedy bin packing approach.
    
    Args:
        df: DataFrame containing question responses
        group_column: Column name for the question identifier
        responses_per_annotator: Target number of responses per annotator
        
    Returns:
        DataFrame with an additional 'annotator_id' column
    """
    result_df = df.copy()
    result_df['annotator_id'] = None
    
    # Get questions and limit to responses_per_annotator
    limited_questions = {}
    for question_id, group in df.groupby(group_column):
        # Take only the first responses_per_annotator rows for each question
        limited_questions[question_id] = min(len(group), responses_per_annotator)
    
    # Map to track which responses have been assigned
    assigned_indices = defaultdict(set)  # question_id -> set of assigned indices
    
    # Track annotator assignments
    annotators = {}  # annotator_id -> [(question_id, num_responses), ...]
    current_annotator = 0
    
    for question_id, num_responses in limited_questions.items():
        # Get the first responses_per_annotator indices for this question
        question_indices = df[df[group_column] == question_id].index.tolist()[:responses_per_annotator]
        remaining_indices = [idx for idx in question_indices if idx not in assigned_indices[question_id]]
        
        actual_num_responses = len(remaining_indices)

        best_fit = None
        best_fit_space = responses_per_annotator + 1  # Initialize to larger than target
        
        for annotator_id, assigned in annotators.items():
            annotator_load = sum(resp for _, resp in assigned)
            available_space = responses_per_annotator - annotator_load
            
            # Find the annotator with the smallest sufficient space
            if actual_num_responses <= available_space and available_space < best_fit_space:
                best_fit = annotator_id
                best_fit_space = available_space
        
        if best_fit is not None:
            # Add question to best fitting annotator
            annotators[best_fit].append((question_id, actual_num_responses))
            
            # Update the result dataframe
            result_df.loc[remaining_indices, 'annotator_id'] = best_fit
            
            # Mark as assigned
            assigned_indices[question_id].update(remaining_indices)
        else:
            # Create new annotator for this question
            annotators[current_annotator] = [(question_id, actual_num_responses)]
            
            # Update the result dataframe
            result_df.loc[remaining_indices, 'annotator_id'] = current_annotator
            
            # Mark as assigned
            assigned_indices[question_id].update(remaining_indices)
            
            current_annotator += 1
    
    return result_df

df = assign_questions_to_annotators(df)
df
# Out:
#                                         id  \
# 0     38f590ee-1964-4a7c-9625-53b53cb8a9f0
# 1     95784937-f565-4450-bfad-babc2399d667
# 2     88c0f433-7fdb-48ad-9898-a08d861635e1
# 3     53c99817-a318-45e5-a918-6b2e7dd4e8d1
# 4     9f3eeb88-7254-402f-b025-b3c0298e2a64
# ...                                    ...
# 1423                                  2257
# 1424                                  1515
# 1425                                  2458
# 1426                                  2794
# 1427                                   232
#
#                                                response  score condition  \
# 0                                              learning      0       NaN
# 1                                                answer      0       NaN
# 2     human observers made live annotations regardin...      0       NaN
# 3     Recorded data from student while doing help ba...      0       NaN
# 4                                     analyzing context      0       NaN
# ...                                                 ...    ...       ...
# 1423  Slow technological progress, natural disasters...      2    stairs
# 1424  Economic conditions before 1870 were sluggish ...      2    stairs
# 1425                      economic conditions were slow      2    stairs
# 1426  Before 1870, economic conditions were relative...      2    stairs
# 1427  The purpose of a "do . . . while " loop in Jav...      2    stairs
#
#                          user_id  \
# 0      clu91tykw0002l00fz3o1vfsh
# 1      cluc0hclp0000ju0flnuywkrr
# 2      clu7cooq9000kjt0fbxh29vfy
# 3      clucz38h40005jv0fhc5vjpfp
# 4      clu8uwkw20000jz0f4yyg6c1d
# ...                          ...
# 1423  pkwlvvzebu2ppqvjop66x5hequ
# 1424  mx25ylobcck2yg2xkiv4srpfh4
# 1425  kwj3wlbqwnfecwceaxe2noulju
# 1426  dggh43s5cosnmyxo57zex3cucy
# 1427  c35eotu6a3guavdkekjwe3346i
#
#                                               page_slug  \
# 0                                             emotional
# 1                                             emotional
# 2                                             emotional
# 3                                             emotional
# 4                                             emotional
# ...                                                 ...
# 1423  7-1-the-relatively-recent-arrival-of-economic-...
# 1424  7-1-the-relatively-recent-arrival-of-economic-...
# 1425  7-1-the-relatively-recent-arrival-of-economic-...
# 1426  7-1-the-relatively-recent-arrival-of-economic-...
# 1427                                2-program-structure
#
#                                              chunk_slug  \
# 0     01-Affect-Detection-from-Student-Activity-Data...
# 1     01-Affect-Detection-from-Student-Activity-Data...
# 2     01-Affect-Detection-from-Student-Activity-Data...
# 3     01-Affect-Detection-from-Student-Activity-Data...
# 4     01-Affect-Detection-from-Student-Activity-Data...
# ...                                                 ...
# 1423                           learning-objectives-700t
# 1424                           learning-objectives-700t
# 1425                           learning-objectives-700t
# 1426                           learning-objectives-700t
# 1427                            while-and-do-Loops-789t
#
#                             created_at          volume_slug  \
# 0              2024-04-15 19:57:38.656              cornell
# 1               2024-05-05 20:29:28.14              cornell
# 2              2024-04-15 19:03:37.985              cornell
# 3              2024-03-30 01:56:12.488              cornell
# 4              2024-05-03 20:56:52.298              cornell
# ...                                ...                  ...
# 1423  2024-08-15 22:19:30.781007+00:00             cttc-poe
# 1424  2024-08-12 18:03:45.775565+00:00             cttc-poe
# 1425  2024-08-15 23:28:39.503359+00:00             cttc-poe
# 1426  2024-08-16 20:43:33.145129+00:00             cttc-poe
# 1427      2024-09-01 20:34:24.20905+00  eloquent-javascript
#
#                         volume_title  \
# 0     Handbook of Learning Analytics
# 1     Handbook of Learning Analytics
# 2     Handbook of Learning Analytics
# 3     Handbook of Learning Analytics
# 4     Handbook of Learning Analytics
# ...                              ...
# 1423    Principles of Macroeconomics
# 1424    Principles of Macroeconomics
# 1425    Principles of Macroeconomics
# 1426    Principles of Macroeconomics
# 1427             Eloquent JavaScript
#
#                                              page_title  \
# 0                          Emotional Learning Analytics
# 1                          Emotional Learning Analytics
# 2                          Emotional Learning Analytics
# 3                          Emotional Learning Analytics
# 4                          Emotional Learning Analytics
# ...                                                 ...
# 1423  7.1 The Relatively Recent Arrival of Economic ...
# 1424  7.1 The Relatively Recent Arrival of Economic ...
# 1425  7.1 The Relatively Recent Arrival of Economic ...
# 1426  7.1 The Relatively Recent Arrival of Economic ...
# 1427                               2. Program Structure
#
#                                          chunk_header  \
# 0     0.1 Affect Detection from Student Activity Data
# 1     0.1 Affect Detection from Student Activity Data
# 2     0.1 Affect Detection from Student Activity Data
# 3     0.1 Affect Detection from Student Activity Data
# 4     0.1 Affect Detection from Student Activity Data
# ...                                               ...
# 1423                              learning objectives
# 1424                              learning objectives
# 1425                              learning objectives
# 1426                              learning objectives
# 1427                               while and do Loops
#
#                                              chunk_text  \
# 0     Affective states cannot be directly measured b...
# 1     Affective states cannot be directly measured b...
# 2     Affective states cannot be directly measured b...
# 3     Affective states cannot be directly measured b...
# 4     Affective states cannot be directly measured b...
# ...                                                 ...
# 1423  Let’s begin with a brief overview of spectacul...
# 1424  Let’s begin with a brief overview of spectacul...
# 1425  Let’s begin with a brief overview of spectacul...
# 1426  Let’s begin with a brief overview of spectacul...
# 1427  Consider a program that outputs all even numbe...
#
#                                                question  \
# 0     What approach was used to infer affect by anal...
# 1     What approach was used to infer affect by anal...
# 2     What approach was used to infer affect by anal...
# 3     What approach was used to infer affect by anal...
# 4     What approach was used to infer affect by anal...
# ...                                                 ...
# 1423    What were economic conditions like before 1870?
# 1424    What were economic conditions like before 1870?
# 1425    What were economic conditions like before 1870?
# 1426    What were economic conditions like before 1870?
# 1427    What is the purpose of a do loop in JavaScript?
#
#                                                  answer  o3_mini_score  \
# 0     The interaction-based, log-file based, or sens...              1
# 1     The interaction-based, log-file based, or sens...              1
# 2     The interaction-based, log-file based, or sens...              2
# 3     The interaction-based, log-file based, or sens...              2
# 4     The interaction-based, log-file based, or sens...              2
# ...                                                 ...            ...
# 1423  Economic conditions before 1870 were marked by...              4
# 1424  Economic conditions before 1870 were marked by...              2
# 1425  Economic conditions before 1870 were marked by...              2
# 1426  Economic conditions before 1870 were marked by...              2
# 1427  A do loop always executes its body at least on...              4
#
#      annotator_id
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ...           ...
# 1423         None
# 1424         None
# 1425         None
# 1426         None
# 1427           39
#
# [1428 rows x 17 columns]

# %%
# Get 12 random annotators
# grouped = list(df.sample(frac=1, random_state=42).groupby("annotator_id"))
# df = pd.concat(g[1] for g in grouped[:12])

# %%
print(df.volume_slug.value_counts())
df.groupby(["annotator_id", "chunk_slug"]).size()
# Out:
# volume_slug
# cornell                                   681
# cttc-poe                                  486
# eloquent-javascript                       206
# business-law-and-the-legal-environment     55
# Name: count, dtype: int64
# annotator_id  chunk_slug
# 0             01-Affect-Detection-from-Student-Activity-Data-480t    30
# 1             02-Affect-Detection-from-Bodily-Signals-481t            6
#               1-Emerging-Themes-482t                                  9
#               2-Future-Themes-487t                                    9
#               Abstract-Data-Types-818t                                2
#                                                                      ..
# 38            header-148t                                             1
# 39            What-For,-Whom,-Why,-How?-Chunk-2-531t                 12
#               introduction-322t                                       2
#               while-and-do-Loops-789t                                 1
# 40            learning-objectives-700t                               30
# Length: 184, dtype: int64

# %%
out_df = (
    df[~df.annotator_id.isna()]
    [[
        "annotator_id", "id", "chunk_header", "chunk_text", "question", "answer", "response"
    ]]
    .rename(columns={
        "id": "question_id",
        "answer": "reference_answer",
    })
    .assign(score="")
)
display(out_df.sample(3))
out_df.to_csv("../../data/itell-cri-data-for-annotators.csv", index=False)
# Out:
#     annotator_id                           question_id  \
# 329           10  31bf81d0-00f1-49e7-93ea-d96ad7b9c436
# 995           31                                  1040
# 437           13  e85ea490-92fc-43bc-9c26-e3976bc037ba
#
#                                        chunk_header  \
# 329  Challenges Facing Learning Analytics About SRL
# 995                 Rule of Law and Economic Growth
# 437                                   Core Themes 3
#
#                                             chunk_text  \
# 329  As software systems gathering trace data evolv...
# 995  Economic growth depends on many factors. Key a...
# 437  One limitation of the face-based affect detect...
#
#                                               question  \
# 329  How do self-regulating learners adapt their sk...
# 995  What factors does economic growth depend on ac...
# 437  What is the advantage of combining interaction...
#
#                                       reference_answer  \
# 329  Self-regulating learners strive to adapt skill...
# 995  Adherence to the rule of law and protection of...
# 437  They can be applied to almost all cases while ...
#
#                                               response score
# 329                              They utilize feedback
# 995  1. Slavery-based societies\n2. Global trading ...
# 437  They can be applied to almost all cases while ...
