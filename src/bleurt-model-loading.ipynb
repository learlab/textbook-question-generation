# %%
import json
import tqdm
import torch
import numpy as np
import matplotlib.pyplot as plt

from collections import Counter
from torch.utils.data import Dataset, DataLoader
from transformers import AutoModelForSequenceClassification, AutoTokenizer
from sklearn.metrics import f1_score, cohen_kappa_score, confusion_matrix, classification_report, ConfusionMatrixDisplay
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 9
#       7 from collections import Counter
#       8 from torch.utils.data import Dataset, DataLoader
# ----> 9 from transformers import AutoModelForSequenceClassification, AutoTokenizer
#      10 from sklearn.metrics import f1_score, cohen_kappa_score, confusion_matrix, classification_report, ConfusionMatrixDisplay
#
# ModuleNotFoundError: No module named 'transformers'

# %%
def generate_metrics(predicted_labels_raw, true_labels, return_metrics=False):

    plt.hist(predicted_labels_raw)
    plt.title('BLEURT Score Distribution')
    plt.show()

    max_f1_at_th = -1.0
    max_f1 = 0.0
    
    for th in np.arange(0.5, 1.0, 0.05):
        th = round(th, 2)
        predicted_labels = [1 if bleurt_score >= th else 0 for bleurt_score in predicted_labels_raw]

        temp_f1 = f1_score(true_labels, predicted_labels)

        if temp_f1 >= max_f1:
            max_f1 = temp_f1
            max_f1_at_th = th

    # printing metrics at the threshold for which we got max F1-Score
    predicted_labels = [1 if bleurt_score >= max_f1_at_th else 0 for bleurt_score in predicted_labels_raw]        

    if return_metrics:
        return max_f1_at_th, f1_score(true_labels, predicted_labels), cohen_kappa_score(true_labels, predicted_labels)
    else:
        print(f'Optimal Threshold: {max_f1_at_th} \n')
        print(f'Predicted Label Count: {Counter(predicted_labels)}\n')
        print('Classification Report:')
        print(classification_report(true_labels, predicted_labels), '\n')
        print('F1 Score: ', f1_score(true_labels, predicted_labels), '\n')
        print('Cohen Kappa: ', cohen_kappa_score(true_labels, predicted_labels), '\n')
        cm_display = ConfusionMatrixDisplay(confusion_matrix = confusion_matrix(true_labels, predicted_labels), display_labels = ['incorrect', 'correct'])
        cm_display.plot()
        plt.show()

    return None

# %%
class BLEURTDataset(Dataset):
    def __init__(self, data, tokenizer):
        self.data = data
        self.tokenizer = tokenizer

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]
        candidate = item["candidate"]
        reference = item["reference"]
        score = item["score"]
        encoding = self.tokenizer(candidate, reference, return_tensors='pt', padding='max_length', truncation=True, max_length=128)
        return {
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'labels': torch.tensor(score, dtype=torch.float)
        }

# %%
# device = "cpu"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = AutoModelForSequenceClassification.from_pretrained("vaiibhavgupta/finetuned-bleurt-large")
# model = AutoModelForSequenceClassification.from_pretrained("/home/jovyan/active-projects/textbook-question-generation/src/multirc-bleurt/model_large_v0")
model.to(device)
model.eval()
tokenizer = AutoTokenizer.from_pretrained("vaiibhavgupta/finetuned-bleurt-large")
# tokenizer = AutoTokenizer.from_pretrained("/home/jovyan/active-projects/textbook-question-generation/src/multirc-bleurt/tokenizer_large_v0")
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/825 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/712k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]

# %%
data_path = "/home/jovyan/active-projects/textbook-question-generation/bleurt-models/bleurtmodel/bleurt/bleurt/test_data/multirc-dataset/{}_samples.jsonl"

with open(data_path.format('test'), 'r') as file:
    test_samples = [json.loads(line) for line in file]

test_dataset = BLEURTDataset(test_samples, tokenizer)
test_loader = DataLoader(test_dataset, batch_size=8)

# %%
predictions = []
true_labels = []
with torch.no_grad():
    for batch in tqdm.tqdm(test_loader):
        true_labels.extend(batch['labels'])
        outputs = model(batch['input_ids'].to(device), attention_mask=batch['attention_mask'].to(device))
        logits = outputs.logits
        preds = logits.detach().cpu().numpy()
        predictions.extend(preds)

# %%
pr = [arr[0] for arr in predictions]
tl = [tn.item() for tn in true_labels]
generate_metrics(pr, tl)

# %%
misclassfified_points = []
for p, t in zip(pr, tl):
    if not int(p > 0.7) == t:
        misclassfified_points.append(p)
len(misclassfified_points)

# %%
480+364

# %%
plt.figure(figsize=(10, 7))
plt.hist(misclassfified_points, alpha=0.7, color='red', label='Misclassified Points')
plt.hist(pr, alpha=0.5, color='blue', label='All Predicted Points')
plt.plot([0.7]*10, [0, 200, 400, 600, 800, 1000, 1200, 1400, 1600, 1750], label='Optimal Threshold')
plt.title('BLEURT scores for all vs misclassified datapoints')
plt.legend(loc='upper right')
plt.show()

# %%
list_of_items = [x for x in test_loader]

# %%
# Out:
# [{'candidate': "The Women's Haven of Tarrant County",
#   'reference': "The Women's Haven of Tarrant County will be able to add a second full-time attorney to its staff and contract with Texas Wesleyan University for pro bono and student services thanks to a two-year, $350,000 grant from the federal Violence Against Women Office.",
#   'score': 1},
#  {'candidate': 'Tarrant county shelters',
#   'reference': "The Women's Haven of Tarrant County will be able to add a second full-time attorney to its staff and contract with Texas Wesleyan University for pro bono and student services thanks to a two-year, $350,000 grant from the federal Violence Against Women Office.",
#   'score': 0},
#  {'candidate': "Female's Safe House of Haven County",
#   'reference': "The Women's Haven of Tarrant County will be able to add a second full-time attorney to its staff and contract with Texas Wesleyan University for pro bono and student services thanks to a two-year, $350,000 grant from the federal Violence Against Women Office.",
#   'score': 0},
#  {'candidate': 'California', 'reference': 'Texas', 'score': 0},
#  {'candidate': 'Texas', 'reference': 'Texas', 'score': 1},
#  {'candidate': 'Tarrant County', 'reference': 'Texas', 'score': 0},
#  {'candidate': 'TX', 'reference': 'Texas', 'score': 1},
#  {'candidate': 'Oklahoma', 'reference': 'Texas', 'score': 0},
#  {'candidate': 'California',
#   'reference': 'In Texas, women who are not legally divorced cannot obtain child support.',
#   'score': 0},
#  {'candidate': 'Texas',
#   'reference': 'In Texas, women who are not legally divorced cannot obtain child support.',
#   'score': 1},
#  {'candidate': 'Tarrant County',
#   'reference': 'In Texas, women who are not legally divorced cannot obtain child support.',
#   'score': 0},
#  {'candidate': 'Oklahoma',
#   'reference': 'In Texas, women who are not legally divorced cannot obtain child support.',
#   'score': 0},
#  {'candidate': 'Tarrant', 'reference': 'Tarrant County', 'score': 1},
#  {'candidate': 'Porter county', 'reference': 'Tarrant County', 'score': 0},
#  {'candidate': 'Midland', 'reference': 'Tarrant County', 'score': 0},
#  {'candidate': 'Tarrant County', 'reference': 'Tarrant County', 'score': 1},
#  {'candidate': 'Add a second full-time attorney to its staff and contract with the law school clinic at Texas Wesleyan University for pro bono and student services',
#   'reference': "The grant money will allow the Women's Haven to add a second full-time attorney to its staff and contract with the law school clinic at Texas Wesleyan University for pro bono and student services, enabling them to provide legal assistance for battered women in matters of divorce or child custody.",
#   'score': 1},
#  {'candidate': 'More food',
#   'reference': "The grant money will allow the Women's Haven to add a second full-time attorney to its staff and contract with the law school clinic at Texas Wesleyan University for pro bono and student services, enabling them to provide legal assistance for battered women in matters of divorce or child custody.",
#   'score': 0},
#  {'candidate': 'Add more room in the shelters',
#   'reference': "The grant money will allow the Women's Haven to add a second full-time attorney to its staff and contract with the law school clinic at Texas Wesleyan University for pro bono and student services, enabling them to provide legal assistance for battered women in matters of divorce or child custody.",
#   'score': 0},
#  {'candidate': 'A second full time attorney',
#   'reference': "The grant money will allow the Women's Haven to add a second full-time attorney to its staff and contract with the law school clinic at Texas Wesleyan University for pro bono and student services, enabling them to provide legal assistance for battered women in matters of divorce or child custody.",
#   'score': 1},
#  {'candidate': 'More legal help',
#   'reference': "The grant money will allow the Women's Haven to add a second full-time attorney to its staff and contract with the law school clinic at Texas Wesleyan University for pro bono and student services, enabling them to provide legal assistance for battered women in matters of divorce or child custody.",
#   'score': 1},
#  {'candidate': 'You cant get welfare',
#   'reference': "In Texas, unlike in some other states, women who are not divorced can't gain full control over their portion of assets and they can't obtain child support.",
#   'score': 0},
#  {'candidate': 'You cannot get child support',
#   'reference': "In Texas, unlike in some other states, women who are not divorced can't gain full control over their portion of assets and they can't obtain child support.",
#   'score': 1},
#  {'candidate': 'No control over assets',
#   'reference': "In Texas, unlike in some other states, women who are not divorced can't gain full control over their portion of assets and they can't obtain child support.",
#   'score': 0},
#  {'candidate': "Women who aren't divorced can't gain full control over their portion of assets. And they can't obtain child support",
#   'reference': "In Texas, unlike in some other states, women who are not divorced can't gain full control over their portion of assets and they can't obtain child support.",
#   'score': 1},
#  {'candidate': 'Control over assets',
#   'reference': "In Texas, unlike in some other states, women who are not divorced can't gain full control over their portion of assets and they can't obtain child support.",
#   'score': 1},
#  {'candidate': "Can't obtain child support",
#   'reference': "In Texas, unlike in some other states, women who are not divorced can't gain full control over their portion of assets and they can't obtain child support.",
#   'score': 0},
#  {'candidate': 'Disabled',
#   'reference': 'The working poor who do not qualify for free legal services are "completely shut out of the civil-law system".',
#   'score': 0},
#  {'candidate': 'Poor divorcee women',
#   'reference': 'The working poor who do not qualify for free legal services are "completely shut out of the civil-law system".',
#   'score': 1},
#  {'candidate': 'The working poor',
#   'reference': 'The working poor who do not qualify for free legal services are "completely shut out of the civil-law system".',
#   'score': 1},
#  {'candidate': 'Rich men',
#   'reference': 'The working poor who do not qualify for free legal services are "completely shut out of the civil-law system".',
#   'score': 0},
#  {'candidate': 'They can afford legal help',
#   'reference': 'The working poor pose a problem for legal aid because they do not qualify for free legal services, and cannot afford to pay for a divorce or child custody battle.',
#   'score': 0},
#  {'candidate': 'It has no effect',
#   'reference': 'The working poor pose a problem for legal aid because they do not qualify for free legal services, and cannot afford to pay for a divorce or child custody battle.',
#   'score': 0},
#  {'candidate': 'They are stuck',
#   'reference': 'The working poor pose a problem for legal aid because they do not qualify for free legal services, and cannot afford to pay for a divorce or child custody battle.',
#   'score': 1},
#  {'candidate': "They don't qualify for free legal services, so they can't file for custody or divorce because it costs too much money. They are completely cut out of the legal system, so they become stuck",
#   'reference': 'The working poor pose a problem for legal aid because they do not qualify for free legal services, and cannot afford to pay for a divorce or child custody battle.',
#   'score': 1},
#  {'candidate': 'There is no problem in Tarrant County',
#   'reference': 'The working poor pose a problem for legal aid because they do not qualify for free legal services, and cannot afford to pay for a divorce or child custody battle.',
#   'score': 0},
#  {'candidate': "They're completely shut out of the civil-law system",
#   'reference': 'The working poor pose a problem for legal aid because they do not qualify for free legal services, and cannot afford to pay for a divorce or child custody battle.',
#   'score': 1},
#  {'candidate': 'They dont qualify',
#   'reference': 'The working poor pose a problem for legal aid because they do not qualify for free legal services, and cannot afford to pay for a divorce or child custody battle.',
#   'score': 1},
#  {'candidate': 'Legal assistance for battered women',
#   'reference': 'Legal assistance for battered women in Tarrant County.',
#   'score': 1},
#  {'candidate': 'Free legal services',
#   'reference': 'Legal assistance for battered women in Tarrant County.',
#   'score': 1},
#  {'candidate': 'Welfare assistance',
#   'reference': 'Legal assistance for battered women in Tarrant County.',
#   'score': 0},
#  {'candidate': 'Finding shelters for battered women',
#   'reference': 'Legal assistance for battered women in Tarrant County.',
#   'score': 0},
#  {'candidate': 'Negative charge',
#   'reference': 'A proton has a positive electric charge.',
#   'score': 0},
#  {'candidate': 'A proton has a negative charge',
#   'reference': 'A proton has a positive electric charge.',
#   'score': 0},
#  {'candidate': 'Neutral',
#   'reference': 'A proton has a positive electric charge.',
#   'score': 0},
#  {'candidate': 'A proton has a neutral charge',
#   'reference': 'A proton has a positive electric charge.',
#   'score': 0},
#  {'candidate': "Protons don't matter because they have no charge",
#   'reference': 'A proton has a positive electric charge.',
#   'score': 0},
#  {'candidate': 'Positive',
#   'reference': 'A proton has a positive electric charge.',
#   'score': 1},
#  {'candidate': 'A proton has a positive electric charge',
#   'reference': 'A proton has a positive electric charge.',
#   'score': 1},
#  {'candidate': 'A proton has a positive charge',
#   'reference': 'A proton has a positive electric charge.',
#   'score': 1},
#  {'candidate': 'A proton has a positive electrical charge',
#   'reference': 'A proton has a positive electric charge.',
#   'score': 1},
#  {'candidate': 'Negative charge',
#   'reference': 'A atom with more electrons than protons has a negative charge.',
#   'score': 1},
#  {'candidate': 'Neutral',
#   'reference': 'A atom with more electrons than protons has a negative charge.',
#   'score': 0},
#  {'candidate': 'Negative',
#   'reference': 'A atom with more electrons than protons has a negative charge.',
#   'score': 1},
#  {'candidate': 'An atom with more electrons than protons has an electrical charge',
#   'reference': 'A atom with more electrons than protons has a negative charge.',
#   'score': 0},
#  {'candidate': 'Electrons have a negative charge',
#   'reference': 'A atom with more electrons than protons has a negative charge.',
#   'score': 1},
#  {'candidate': "An atom can't have more electrons than protons",
#   'reference': 'A atom with more electrons than protons has a negative charge.',
#   'score': 0},
#  {'candidate': 'Positive charge',
#   'reference': 'A atom with more electrons than protons has a negative charge.',
#   'score': 0},
#  {'candidate': "Electrons and protons don't have to touch",
#   'reference': 'A atom with more electrons than protons has a negative charge.',
#   'score': 0},
#  {'candidate': 'An atom with more electrons than protons will have a negative charge',
#   'reference': 'A atom with more electrons than protons has a negative charge.',
#   'score': 1},
#  {'candidate': "Neutrons don't matter because they have no charge",
#   'reference': "Increasing neutrons will not affect the particle's charge. Neutrons have no charge, so the number of protons and electrons in the atom will remain the same.",
#   'score': 1},
#  {'candidate': 'Increasing neutrons makes a charge more positive',
#   'reference': "Increasing neutrons will not affect the particle's charge. Neutrons have no charge, so the number of protons and electrons in the atom will remain the same.",
#   'score': 0},
#  {'candidate': 'Increasing neutrons will create a negative charge',
#   'reference': "Increasing neutrons will not affect the particle's charge. Neutrons have no charge, so the number of protons and electrons in the atom will remain the same.",
#   'score': 0},
#  {'candidate': 'Not at all',
#   'reference': "Increasing neutrons will not affect the particle's charge. Neutrons have no charge, so the number of protons and electrons in the atom will remain the same.",
#   'score': 1},
#  {'candidate': "Increasing neutrons in a particle will make it's charge even more neutral",
#   'reference': "Increasing neutrons will not affect the particle's charge. Neutrons have no charge, so the number of protons and electrons in the atom will remain the same.",
#   'score': 0},
#  {'candidate': 'No change',
#   'reference': "Increasing neutrons will not affect the particle's charge. Neutrons have no charge, so the number of protons and electrons in the atom will remain the same.",
#   'score': 1},
#  {'candidate': "Neutrons do not affect the particle's charge?",
#   'reference': "Increasing neutrons will not affect the particle's charge. Neutrons have no charge, so the number of protons and electrons in the atom will remain the same.",
#   'score': 1},
#  {'candidate': 'Positive',
#   'reference': "Increasing neutrons will not affect the particle's charge. Neutrons have no charge, so the number of protons and electrons in the atom will remain the same.",
#   'score': 0},
#  {'candidate': "Gaining or losing neutrons don't change a particle's charge",
#   'reference': "Increasing neutrons will not affect the particle's charge. Neutrons have no charge, so the number of protons and electrons in the atom will remain the same.",
#   'score': 1},
#  {'candidate': "Increasing neutrons do not affect a particle's charge",
#   'reference': "Increasing neutrons will not affect the particle's charge. Neutrons have no charge, so the number of protons and electrons in the atom will remain the same.",
#   'score': 1},
#  {'candidate': 'More neutrons will make an object become positively charged',
#   'reference': "An object's charge becomes positive when it loses some electrons, resulting in more protons than electrons inside the atom.",
#   'score': 0},
#  {'candidate': 'When an object loses electrons',
#   'reference': "An object's charge becomes positive when it loses some electrons, resulting in more protons than electrons inside the atom.",
#   'score': 1},
#  {'candidate': 'When an object loses some electrons,it becomes positive',
#   'reference': "An object's charge becomes positive when it loses some electrons, resulting in more protons than electrons inside the atom.",
#   'score': 1},
#  {'candidate': 'When an object has more electrons than protons',
#   'reference': "An object's charge becomes positive when it loses some electrons, resulting in more protons than electrons inside the atom.",
#   'score': 0},
#  {'candidate': 'When there are more protons than electrons inside the atom',
#   'reference': "An object's charge becomes positive when it loses some electrons, resulting in more protons than electrons inside the atom.",
#   'score': 1},
#  {'candidate': 'Because neutrons have no charge',
#   'reference': "An object's charge becomes positive when it loses some electrons, resulting in more protons than electrons inside the atom.",
#   'score': 0},
#  {'candidate': 'When an object has more protons than electrons, it becomes positively charged',
#   'reference': "An object's charge becomes positive when it loses some electrons, resulting in more protons than electrons inside the atom.",
#   'score': 1},
#  {'candidate': 'Electrons are lost',
#   'reference': "An object's charge becomes positive when it loses some electrons, resulting in more protons than electrons inside the atom.",
#   'score': 1},
#  {'candidate': 'When electrons attach to another object',
#   'reference': "An object's charge becomes positive when it loses some electrons, resulting in more protons than electrons inside the atom.",
#   'score': 0},
#  {'candidate': 'An object becomes positively charged when it loses some electrons',
#   'reference': "An object's charge becomes positive when it loses some electrons, resulting in more protons than electrons inside the atom.",
#   'score': 1},
#  {'candidate': 'An object becomes positively charged when it has more electrons than protons',
#   'reference': "An object's charge becomes positive when it loses some electrons, resulting in more protons than electrons inside the atom.",
#   'score': 0},
#  {'candidate': 'Lost protons may remain free',
#   'reference': 'A particle with more protons than electrons has a positive charge.',
#   'score': 0},
#  {'candidate': 'Negative charge',
#   'reference': 'A particle with more protons than electrons has a positive charge.',
#   'score': 0},
#  {'candidate': 'Protons have a positive charge',
#   'reference': 'A particle with more protons than electrons has a positive charge.',
#   'score': 1},
#  {'candidate': 'An atom with more protons than electrons has a positive charge',
#   'reference': 'A particle with more protons than electrons has a positive charge.',
#   'score': 1},
#  {'candidate': 'A particle will have an equal number of protons and electrons',
#   'reference': 'A particle with more protons than electrons has a positive charge.',
#   'score': 0},
#  {'candidate': 'Negative',
#   'reference': 'A particle with more protons than electrons has a positive charge.',
#   'score': 0},
#  {'candidate': 'A particle with more protons than electrons has a negative charge',
#   'reference': 'A particle with more protons than electrons has a positive charge.',
#   'score': 0},
#  {'candidate': 'Positive charge',
#   'reference': 'A particle with more protons than electrons has a positive charge.',
#   'score': 1},
#  {'candidate': 'It is positively charged',
#   'reference': 'A particle with more protons than electrons has a positive charge.',
#   'score': 1},
#  {'candidate': 'A particle with more protons than electrons will have a positive charge',
#   'reference': 'A particle with more protons than electrons has a positive charge.',
#   'score': 1},
#  {'candidate': 'Positive',
#   'reference': 'A particle with more protons than electrons has a positive charge.',
#   'score': 1},
#  {'candidate': 'A physical charge between them',
#   'reference': 'Electric charge caused by protons and electrons in atoms is what causes objects to attract or repel each other.',
#   'score': 1},
#  {'candidate': 'Objects are attracted or repelled because of the number of neutrons in them',
#   'reference': 'Electric charge caused by protons and electrons in atoms is what causes objects to attract or repel each other.',
#   'score': 0},
#  {'candidate': 'Objects attract or repel each other because of a physical charge between them',
#   'reference': 'Electric charge caused by protons and electrons in atoms is what causes objects to attract or repel each other.',
#   'score': 1},
#  {'candidate': 'Protons',
#   'reference': 'Electric charge caused by protons and electrons in atoms is what causes objects to attract or repel each other.',
#   'score': 0},
#  {'candidate': 'Protons and electrons',
#   'reference': 'Electric charge caused by protons and electrons in atoms is what causes objects to attract or repel each other.',
#   'score': 1},
#  {'candidate': 'Electric charge',
#   'reference': 'Electric charge caused by protons and electrons in atoms is what causes objects to attract or repel each other.',
#   'score': 1},
#  {'candidate': 'Electrical charge',
#   'reference': 'Electric charge caused by protons and electrons in atoms is what causes objects to attract or repel each other.',
#   'score': 1},
#  {'candidate': 'Particles',
#   'reference': 'Electric charge caused by protons and electrons in atoms is what causes objects to attract or repel each other.',
#   'score': 0},
#  {'candidate': 'An electron charge causes objects to attract or repel each other',
#   'reference': 'Electric charge caused by protons and electrons in atoms is what causes objects to attract or repel each other.',
#   'score': 0},
#  {'candidate': 'Objects',
#   'reference': 'Electric charge caused by protons and electrons in atoms is what causes objects to attract or repel each other.',
#   'score': 0},
#  {'candidate': 'Proton charge',
#   'reference': 'Attraction or repulsion.',
#   'score': 0},
#  {'candidate': 'A physical property between particles and objects is an electrical charge',
#   'reference': 'Attraction or repulsion.',
#   'score': 1},
#  {'candidate': 'Neutrons',
#   'reference': 'Attraction or repulsion.',
#   'score': 0},
#  {'candidate': 'A nuclear charge between two objects is a physical property that occurs',
#   'reference': 'Attraction or repulsion.',
#   'score': 0},
#  {'candidate': 'Attraction and repulsion',
#   'reference': 'Attraction or repulsion.',
#   'score': 0},
#  {'candidate': 'Protons and electrons',
#   'reference': 'Attraction or repulsion.',
#   'score': 0},
#  {'candidate': 'Electric charge',
#   'reference': 'Attraction or repulsion.',
#   'score': 1},
#  {'candidate': 'Electrical charge is a physical property that occurs between particles and objects',
#   'reference': 'Attraction or repulsion.',
#   'score': 1},
#  {'candidate': 'Electrical charge',
#   'reference': 'Attraction or repulsion.',
#   'score': 1},
#  {'candidate': 'A neutron charge causes particles to attract or repel each other',
#   'reference': 'Electric charge',
#   'score': 0},
#  {'candidate': 'Atoms cause particles to attract or repel each other',
#   'reference': 'Electric charge',
#   'score': 0},
#  {'candidate': 'An electrical charge',
#   'reference': 'Electric charge',
#   'score': 1},
#  {'candidate': 'A proton charge', 'reference': 'Electric charge', 'score': 0},
#  {'candidate': 'Electric charge', 'reference': 'Electric charge', 'score': 1},
#  {'candidate': 'Electrical charge causes particles to attract or repel each other',
#   'reference': 'Electric charge',
#   'score': 1},
#  {'candidate': 'Positive charge', 'reference': 'Electric charge', 'score': 0},
#  {'candidate': 'Electric charge is the physical property that causes particles to attract or repel each other',
#   'reference': 'Electric charge',
#   'score': 1},
#  {'candidate': 'A physical property occurs between particles or objects',
#   'reference': 'Electric charge',
#   'score': 0},
#  {'candidate': 'When a particle loses some protons, it has a negative charge',
#   'reference': "The particle's charge will depend on the number of protons and electrons it has; if it has lost some protons, it will be positively charged.",
#   'score': 1},
#  {'candidate': 'Neutral',
#   'reference': "The particle's charge will depend on the number of protons and electrons it has; if it has lost some protons, it will be positively charged.",
#   'score': 0},
#  {'candidate': 'When a particle loses some of its protons, it becomes positive',
#   'reference': "The particle's charge will depend on the number of protons and electrons it has; if it has lost some protons, it will be positively charged.",
#   'score': 0},
#  {'candidate': 'Negative',
#   'reference': "The particle's charge will depend on the number of protons and electrons it has; if it has lost some protons, it will be positively charged.",
#   'score': 1},
#  {'candidate': 'It is negativity charged',
#   'reference': "The particle's charge will depend on the number of protons and electrons it has; if it has lost some protons, it will be positively charged.",
#   'score': 1},
#  {'candidate': 'Lost protons will attach to another particle',
#   'reference': "The particle's charge will depend on the number of protons and electrons it has; if it has lost some protons, it will be positively charged.",
#   'score': 0},
#  {'candidate': 'When a particle loses protons, it becomes negatively charged',
#   'reference': "The particle's charge will depend on the number of protons and electrons it has; if it has lost some protons, it will be positively charged.",
#   'score': 1},
#  {'candidate': 'If a particle has more electrons than protons, it has a negative charge',
#   'reference': "The particle's charge will depend on the number of protons and electrons it has; if it has lost some protons, it will be positively charged.",
#   'score': 1},
#  {'candidate': 'Negatively charged',
#   'reference': "The particle's charge will depend on the number of protons and electrons it has; if it has lost some protons, it will be positively charged.",
#   'score': 1},
#  {'candidate': 'An object can lose protons and still be electrically balanced',
#   'reference': "The particle's charge will depend on the number of protons and electrons it has; if it has lost some protons, it will be positively charged.",
#   'score': 0},
#  {'candidate': 'Positively charged',
#   'reference': "The particle's charge will depend on the number of protons and electrons it has; if it has lost some protons, it will be positively charged.",
#   'score': 0},
#  {'candidate': 'The Haupert Humanitarian Award',
#   'reference': "Answer:The Haupert Humanitarian Award will be presented on Moravian's Priscilla Payne Hurd campus.",
#   'score': 1},
#  {'candidate': 'Moravian College Alumni Association award',
#   'reference': "Answer:The Haupert Humanitarian Award will be presented on Moravian's Priscilla Payne Hurd campus.",
#   'score': 0},
#  {'candidate': 'OSCAR',
#   'reference': "Answer:The Haupert Humanitarian Award will be presented on Moravian's Priscilla Payne Hurd campus.",
#   'score': 0},
#  {'candidate': 'Kristin Glenn',
#   'reference': 'Fred Rooney crafted a law practice catering to working-class families who are mostly Latino.',
#   'score': 0},
#  {'candidate': 'Fred Rooney',
#   'reference': 'Fred Rooney crafted a law practice catering to working-class families who are mostly Latino.',
#   'score': 1},
#  {'candidate': 'Priscilla Payne',
#   'reference': 'Fred Rooney crafted a law practice catering to working-class families who are mostly Latino.',
#   'score': 0},
#  {'candidate': 'Rooney has worked at Community Legal Resource Network and Lehigh Valley Legal Services',
#   'reference': 'Fred Rooney has worked at Lehigh Valley Legal Services and City University of New York Law School.',
#   'score': 1},
#  {'candidate': 'He worked in New York Law School in Queens',
#   'reference': 'Fred Rooney has worked at Lehigh Valley Legal Services and City University of New York Law School.',
#   'score': 0},
#  {'candidate': 'He has worked in southern Bethlehem as a Lawyer',
#   'reference': 'Fred Rooney has worked at Lehigh Valley Legal Services and City University of New York Law School.',
#   'score': 1},
#  {'candidate': 'Midwest',
#   'reference': 'Fred Rooney has worked at Lehigh Valley Legal Services and City University of New York Law School.',
#   'score': 0},
#  {'candidate': 'South Bethlehem',
#   'reference': 'Fred Rooney has worked at Lehigh Valley Legal Services and City University of New York Law School.',
#   'score': 1},
#  {'candidate': 'Innovative Community Legal Resources Network',
#   'reference': 'Kristin Booth Glen is the dean of the City University of New York Law School.',
#   'score': 0},
#  {'candidate': 'City University of New York Law School',
#   'reference': 'Kristin Booth Glen is the dean of the City University of New York Law School.',
#   'score': 1},
#  {'candidate': 'City University of New York Law School in Queens',
#   'reference': 'Kristin Booth Glen is the dean of the City University of New York Law School.',
#   'score': 1},
#  {'candidate': 'Cornell University',
#   'reference': 'Kristin Booth Glen is the dean of the City University of New York Law School.',
#   'score': 0},
#  {'candidate': 'College Graduation',
#   'reference': 'The event that Rooney described as being his "guiding light" was a trip to Colombia when he was a junior at Moravian College.',
#   'score': 0},
#  {'candidate': 'His triip to Colombia',
#   'reference': 'The event that Rooney described as being his "guiding light" was a trip to Colombia when he was a junior at Moravian College.',
#   'score': 1},
#  {'candidate': 'When he compared the suffering, malnutrition and poverty of the Colombians to his',
#   'reference': 'The event that Rooney described as being his "guiding light" was a trip to Colombia when he was a junior at Moravian College.',
#   'score': 0},
#  {'candidate': 'Trip to Colombia',
#   'reference': 'The event that Rooney described as being his "guiding light" was a trip to Colombia when he was a junior at Moravian College.',
#   'score': 1},
#  {'candidate': 'Mickey Rooney',
#   'reference': "Fred Rooney graduated from CUNY Law School's first class in 1986.",
#   'score': 0},
#  {'candidate': 'His brother J. T Rooney',
#   'reference': "Fred Rooney graduated from CUNY Law School's first class in 1986.",
#   'score': 0},
#  {'candidate': 'Fred Rooney',
#   'reference': "Fred Rooney graduated from CUNY Law School's first class in 1986.",
#   'score': 1},
#  {'candidate': 'City University School in Queens New York',
#   'reference': 'Answer:Kristin Booth Glen is the dean of the City University of New York Law School.',
#   'score': 0},
#  {'candidate': 'City University of New York',
#   'reference': 'Answer:Kristin Booth Glen is the dean of the City University of New York Law School.',
#   'score': 1},
#  {'candidate': 'Cornell',
#   'reference': 'Answer:Kristin Booth Glen is the dean of the City University of New York Law School.',
#   'score': 0},
#  {'candidate': 'City University of New York Law School',
#   'reference': 'Answer:Kristin Booth Glen is the dean of the City University of New York Law School.',
#   'score': 1},
#  {'candidate': 'He appeared innocent,was lanky and wearing black bluejeans and a button down shirt',
#   'reference': 'Fred Rooney has a Jimmy Stewart-like quality of quiet trust, is lanky, and wears black jeans and a button-down shirt.',
#   'score': 1},
#  {'candidate': 'He looks like a good guy',
#   'reference': 'Fred Rooney has a Jimmy Stewart-like quality of quiet trust, is lanky, and wears black jeans and a button-down shirt.',
#   'score': 0},
#  {'candidate': 'Quiet trust',
#   'reference': 'Fred Rooney has a Jimmy Stewart-like quality of quiet trust, is lanky, and wears black jeans and a button-down shirt.',
#   'score': 1},
#  {'candidate': 'Suspicious',
#   'reference': 'Fred Rooney has a Jimmy Stewart-like quality of quiet trust, is lanky, and wears black jeans and a button-down shirt.',
#   'score': 0},
#  {'candidate': 'He provides legal representation to those who cannot afford a lawyer',
#   'reference': 'Fred Rooney is a lawyer.',
#   'score': 1},
#  {'candidate': 'Professor',
#   'reference': 'Fred Rooney is a lawyer.',
#   'score': 0},
#  {'candidate': 'Lawyer', 'reference': 'Fred Rooney is a lawyer.', 'score': 1},
#  {'candidate': 'Lehigh Valley Legal Services',
#   'reference': 'Fred Rooney is a lawyer.',
#   'score': 0},
#  {'candidate': 'Fred Rooney and his brother',
#   'reference': 'Fred Rooney has a Jimmy Stewart-like quality of quiet trust.',
#   'score': 0},
#  {'candidate': 'Kristin Glenn',
#   'reference': 'Fred Rooney has a Jimmy Stewart-like quality of quiet trust.',
#   'score': 0},
#  {'candidate': 'Fred Rooney',
#   'reference': 'Fred Rooney has a Jimmy Stewart-like quality of quiet trust.',
#   'score': 1},
#  {'candidate': 'He has more of a  trace of childish innocence',
#   'reference': "Fred's demeanor can be described as low-key, captivating, inspiring loyalty, and driven by a deep sense of social justice.",
#   'score': 0},
#  {'candidate': 'He was low keyed and captivated people',
#   'reference': "Fred's demeanor can be described as low-key, captivating, inspiring loyalty, and driven by a deep sense of social justice.",
#   'score': 1},
#  {'candidate': 'Quiet trust',
#   'reference': "Fred's demeanor can be described as low-key, captivating, inspiring loyalty, and driven by a deep sense of social justice.",
#   'score': 1},
#  {'candidate': 'He has more of a Jimmy Stewart like countenance',
#   'reference': "Fred's demeanor can be described as low-key, captivating, inspiring loyalty, and driven by a deep sense of social justice.",
#   'score': 1},
#  {'candidate': 'Suspicious',
#   'reference': "Fred's demeanor can be described as low-key, captivating, inspiring loyalty, and driven by a deep sense of social justice.",
#   'score': 0},
#  {'candidate': 'Kristin Booth Glen',
#   'reference': "Kristin Booth Glen, the law school's dean, said that Fred Rooney inspires loyalty.",
#   'score': 1},
#  {'candidate': 'The Alumni of the colleges',
#   'reference': "Kristin Booth Glen, the law school's dean, said that Fred Rooney inspires loyalty.",
#   'score': 0},
#  {'candidate': 'Kristin Glenn',
#   'reference': "Kristin Booth Glen, the law school's dean, said that Fred Rooney inspires loyalty.",
#   'score': 1},
#  {'candidate': 'Fred Rooney',
#   'reference': "Kristin Booth Glen, the law school's dean, said that Fred Rooney inspires loyalty.",
#   'score': 0},
#  {'candidate': 'The Haupert Humanitarian Award',
#   'reference': 'The Haupert Humanitarian Award is given to only a select few alumni of Moravian College.',
#   'score': 1},
#  {'candidate': 'OSCAR',
#   'reference': 'The Haupert Humanitarian Award is given to only a select few alumni of Moravian College.',
#   'score': 0},
#  {'candidate': "The prestigious Moravian's Priscilla Payne award",
#   'reference': 'The Haupert Humanitarian Award is given to only a select few alumni of Moravian College.',
#   'score': 0},
#  {'candidate': 'He grew up in Bethlehem',
#   'reference': 'Fred Rooney grew up in an affluent upbringing on Long Island.',
#   'score': 0},
#  {'candidate': 'Bethlehem',
#   'reference': 'Fred Rooney grew up in an affluent upbringing on Long Island.',
#   'score': 0},
#  {'candidate': 'Long Island',
#   'reference': 'Fred Rooney grew up in an affluent upbringing on Long Island.',
#   'score': 1},
#  {'candidate': 'He grew up in Long Island',
#   'reference': 'Fred Rooney grew up in an affluent upbringing on Long Island.',
#   'score': 1},
#  {'candidate': 'A skillful detective',
#   'reference': 'Charlie believed that the friends of Louise were trying and failing to find her.',
#   'score': 0},
#  {'candidate': 'Her friends',
#   'reference': 'Charlie believed that the friends of Louise were trying and failing to find her.',
#   'score': 1},
#  {'candidate': 'Madame Cerise',
#   'reference': 'Charlie believed that the friends of Louise were trying and failing to find her.',
#   'score': 0},
#  {'candidate': 'Mershone',
#   'reference': 'Charlie believed that the friends of Louise were trying and failing to find her.',
#   'score': 0},
#  {'candidate': "Louise's friends",
#   'reference': 'Charlie believed that the friends of Louise were trying and failing to find her.',
#   'score': 1},
#  {'candidate': 'Friends of Louise',
#   'reference': 'Charlie believed that the friends of Louise were trying and failing to find her.',
#   'score': 1},
#  {'candidate': 'He wore a walking suit',
#   'reference': "Charlie was wearing a dress-coat when he was released at six o'clock.",
#   'score': 0},
#  {'candidate': 'He wore a dress-coat',
#   'reference': "Charlie was wearing a dress-coat when he was released at six o'clock.",
#   'score': 1},
#  {'candidate': 'He wore a suit',
#   'reference': "Charlie was wearing a dress-coat when he was released at six o'clock.",
#   'score': 0},
#  {'candidate': 'Walking suit',
#   'reference': "Charlie was wearing a dress-coat when he was released at six o'clock.",
#   'score': 0},
#  {'candidate': 'A dress coat',
#   'reference': "Charlie was wearing a dress-coat when he was released at six o'clock.",
#   'score': 1},
#  {'candidate': 'She is at The East Orange house',
#   'reference': 'No, Louise and Charlie were not in the same place.',
#   'score': 1},
#  {'candidate': 'They were not',
#   'reference': 'No, Louise and Charlie were not in the same place.',
#   'score': 1},
#  {'candidate': 'They were',
#   'reference': 'No, Louise and Charlie were not in the same place.',
#   'score': 0},
#  {'candidate': 'They are both at a hotel',
#   'reference': 'No, Louise and Charlie were not in the same place.',
#   'score': 0},
#  {'candidate': 'He is at the Bruxtelle',
#   'reference': 'No, Louise and Charlie were not in the same place.',
#   'score': 1},
#  {'candidate': 'Not at all',
#   'reference': 'No, the sculpture is not heavy.',
#   'score': 0},
#  {'candidate': 'Slightly',
#   'reference': 'No, the sculpture is not heavy.',
#   'score': 0},
#  {'candidate': 'Very light',
#   'reference': 'No, the sculpture is not heavy.',
#   'score': 0},
#  {'candidate': 'Yes it is',
#   'reference': 'No, the sculpture is not heavy.',
#   'score': 1},
#  {'candidate': "In Tasha's house",
#   'reference': "Frodo lives around Malaquez's parcel.",
#   'score': 0},
#  {'candidate': 'Under the sculptures',
#   'reference': "Frodo lives around Malaquez's parcel.",
#   'score': 0},
#  {'candidate': "Within the narrator's range",
#   'reference': "Frodo lives around Malaquez's parcel.",
#   'score': 1},
#  {'candidate': 'Somewhere near the narrator',
#   'reference': "Frodo lives around Malaquez's parcel.",
#   'score': 1},
#  {'candidate': 'Around a trash fire',
#   'reference': "Frodo lives around Malaquez's parcel.",
#   'score': 0},
#  {'candidate': 'Somewhere around the hill',
#   'reference': "Frodo lives around Malaquez's parcel.",
#   'score': 1},
#  {'candidate': 'Underground',
#   'reference': "Frodo lives around Malaquez's parcel.",
#   'score': 0},
#  {'candidate': 'Tunnels',
#   'reference': "Frodo lives around Malaquez's parcel.",
#   'score': 0},
#  {'candidate': 'Somewhere nearby',
#   'reference': "Frodo lives around Malaquez's parcel.",
#   'score': 1},
#  {'candidate': 'White colour',
#   'reference': 'Tasha suggested the name "Frodo" for the greenmunk due to its big, furry feet.',
#   'score': 0},
#  {'candidate': 'Big ears',
#   'reference': 'Tasha suggested the name "Frodo" for the greenmunk due to its big, furry feet.',
#   'score': 0},
#  {'candidate': 'From his being lightweight',
#   'reference': 'Tasha suggested the name "Frodo" for the greenmunk due to its big, furry feet.',
#   'score': 0},
#  {'candidate': 'Little',
#   'reference': 'Tasha suggested the name "Frodo" for the greenmunk due to its big, furry feet.',
#   'score': 1},
#  {'candidate': 'From his fondness of sculptures',
#   'reference': 'Tasha suggested the name "Frodo" for the greenmunk due to its big, furry feet.',
#   'score': 0},
#  {'candidate': 'From his habit of running to people',
#   'reference': 'Tasha suggested the name "Frodo" for the greenmunk due to its big, furry feet.',
#   'score': 0},
#  {'candidate': 'From his small size and big furry feet',
#   'reference': 'Tasha suggested the name "Frodo" for the greenmunk due to its big, furry feet.',
#   'score': 1},
#  {'candidate': 'Furry feet',
#   'reference': 'Tasha suggested the name "Frodo" for the greenmunk due to its big, furry feet.',
#   'score': 1},
#  {'candidate': 'From his furry feet and small size',
#   'reference': 'Tasha suggested the name "Frodo" for the greenmunk due to its big, furry feet.',
#   'score': 1},
#  {'candidate': 'Frodo is a pet',
#   'reference': "No, Frodo is not the narrator's pet.",
#   'score': 0},
#  {'candidate': 'Frodo is wild',
#   'reference': "No, Frodo is not the narrator's pet.",
#   'score': 0},
#  {'candidate': 'No, he is not',
#   'reference': "No, Frodo is not the narrator's pet.",
#   'score': 1},
#  {'candidate': 'Yes',
#   'reference': "No, Frodo is not the narrator's pet.",
#   'score': 0},
#  {'candidate': 'Yeah',
#   'reference': "No, Frodo is not the narrator's pet.",
#   'score': 0},
#  {'candidate': 'Yes he did',
#   'reference': 'No, Tasha did not know that the sculpture was heavy.',
#   'score': 1},
#  {'candidate': 'Definitely not',
#   'reference': 'No, Tasha did not know that the sculpture was heavy.',
#   'score': 0},
#  {'candidate': 'As an an explosives expert',
#   'reference': 'Spider is hired to rob a train carrying gold from Russia to Romania.',
#   'score': 0},
#  {'candidate': 'The car',
#   'reference': 'Spider is hired to rob a train carrying gold from Russia to Romania.',
#   'score': 0},
#  {'candidate': 'The train',
#   'reference': 'Spider is hired to rob a train carrying gold from Russia to Romania.',
#   'score': 1},
#  {'candidate': 'To breaks into the house and murder Victor',
#   'reference': 'Spider is hired to rob a train carrying gold from Russia to Romania.',
#   'score': 0},
#  {'candidate': 'To join them in the robbery',
#   'reference': 'Spider is hired to rob a train carrying gold from Russia to Romania.',
#   'score': 1},
#  {'candidate': 'Raj',
#   'reference': 'Ronnie tries to stop the world-class hacker and gets killed.',
#   'score': 0},
#  {'candidate': 'Sunny',
#   'reference': 'Ronnie tries to stop the world-class hacker and gets killed.',
#   'score': 0},
#  {'candidate': 'Don',
#   'reference': 'Ronnie tries to stop the world-class hacker and gets killed.',
#   'score': 0},
#  {'candidate': 'Victor',
#   'reference': 'Ronnie tries to stop the world-class hacker and gets killed.',
#   'score': 0},
#  {'candidate': 'Russian mafia',
#   'reference': 'Ronnie tries to stop the world-class hacker and gets killed.',
#   'score': 0},
#  {'candidate': 'Ronnie',
#   'reference': 'Ronnie tries to stop the world-class hacker and gets killed.',
#   'score': 1},
#  {'candidate': 'Riya',
#   'reference': 'Ronnie tries to stop the world-class hacker and gets killed.',
#   'score': 0},
#  {'candidate': 'Mascarenhas', 'reference': 'Braganza', 'score': 0},
#  {'candidate': 'Victor', 'reference': 'Braganza', 'score': 1},
#  {'candidate': 'Braganza', 'reference': 'Braganza', 'score': 1},
#  {'candidate': 'Ronnie', 'reference': 'Braganza', 'score': 0},
#  {'candidate': 'Bashir', 'reference': 'Braganza', 'score': 0},
#  {'candidate': 'A prosthetic makeup artist',
#   'reference': "Ronnie's job was to use his illusion to trick the soldiers guarding the gold.",
#   'score': 0},
#  {'candidate': 'An explosives expert',
#   'reference': "Ronnie's job was to use his illusion to trick the soldiers guarding the gold.",
#   'score': 0},
#  {'candidate': 'An illusionist',
#   'reference': "Ronnie's job was to use his illusion to trick the soldiers guarding the gold.",
#   'score': 1},
#  {'candidate': 'Vendor',
#   'reference': "Ronnie's job was to use his illusion to trick the soldiers guarding the gold.",
#   'score': 0},
#  {'candidate': 'Raj',
#   'reference': 'Charlie and his accomplice Riya hired a team of criminals to join them in the robbery.',
#   'score': 0},
#  {'candidate': 'Don',
#   'reference': 'Charlie and his accomplice Riya hired a team of criminals to join them in the robbery.',
#   'score': 0},
#  {'candidate': 'Victor',
#   'reference': 'Charlie and his accomplice Riya hired a team of criminals to join them in the robbery.',
#   'score': 0},
#  {'candidate': 'Charlie, Don and Victor',
#   'reference': 'Charlie and his accomplice Riya hired a team of criminals to join them in the robbery.',
#   'score': 1},
#  {'candidate': 'Russian mafia',
#   'reference': 'Charlie and his accomplice Riya hired a team of criminals to join them in the robbery.',
#   'score': 0},
#  {'candidate': 'Ronnie',
#   'reference': 'Charlie and his accomplice Riya hired a team of criminals to join them in the robbery.',
#   'score': 0},
#  {'candidate': 'Charlie',
#   'reference': 'Charlie and his accomplice Riya hired a team of criminals to join them in the robbery.',
#   'score': 1},
#  {'candidate': 'Raj',
#   'reference': 'Charlie puts together the team that robs the train.',
#   'score': 0},
#  {'candidate': 'Charlie, and Victor Braganza hire a team of criminals for the robbery',
#   'reference': 'Charlie puts together the team that robs the train.',
#   'score': 1},
#  {'candidate': 'Don',
#   'reference': 'Charlie puts together the team that robs the train.',
#   'score': 0},
#  {'candidate': 'Victor',
#   'reference': 'Charlie puts together the team that robs the train.',
#   'score': 0},
#  {'candidate': 'Russian mafia',
#   'reference': 'Charlie puts together the team that robs the train.',
#   'score': 0},
#  {'candidate': 'Ronnie',
#   'reference': 'Charlie puts together the team that robs the train.',
#   'score': 0},
#  {'candidate': 'Charlie',
#   'reference': 'Charlie puts together the team that robs the train.',
#   'score': 1},
#  {'candidate': 'While the robbery was being executed',
#   'reference': 'Ronnie stopped Spider during the robbery.',
#   'score': 0},
#  {'candidate': 'When Spider double crosses the gang and tries to flee with gold',
#   'reference': 'Ronnie stopped Spider during the robbery.',
#   'score': 1},
#  {'candidate': 'When he double crosses the gang and tries to flee with all the gold',
#   'reference': 'Ronnie stopped Spider during the robbery.',
#   'score': 1},
#  {'candidate': 'At a party',
#   'reference': 'Ronnie stopped Spider during the robbery.',
#   'score': 0},
#  {'candidate': 'When he tried to flee with all of the gold',
#   'reference': 'Ronnie stopped Spider during the robbery.',
#   'score': 1},
#  {'candidate': 'Spider is going to assassinate her father',
#   'reference': "Naina is devastated by Spider's betrayal and the death of her father.",
#   'score': 1},
#  {'candidate': 'Spider has affair with Naina',
#   'reference': "Naina is devastated by Spider's betrayal and the death of her father.",
#   'score': 0},
#  {'candidate': 'Her father, Victor is killed by assassins. She also learns her father and Charlie are criminals',
#   'reference': "Naina is devastated by Spider's betrayal and the death of her father.",
#   'score': 1},
#  {'candidate': 'She gets in trouble',
#   'reference': "Naina is devastated by Spider's betrayal and the death of her father.",
#   'score': 0},
#  {'candidate': 'Her father is murdered',
#   'reference': "Naina is devastated by Spider's betrayal and the death of her father.",
#   'score': 1},
#  {'candidate': 'Spider is in love with Naina',
#   'reference': "Naina is devastated by Spider's betrayal and the death of her father.",
#   'score': 0},
#  {'candidate': "Naina is Spider's boss",
#   'reference': "Naina is devastated by Spider's betrayal and the death of her father.",
#   'score': 0},
#  {'candidate': 'He used his illusion to trick the soldiers guarding the gold',
#   'reference': "When Spider double-crosses the gang, he tries to flee with all of the gold and is stopped by Ronnie, who is then shot multiple times by Spider's assassins. The group are chased by the assassins and Ronnie and Riya are killed. Spider blows up the location and flees with the gold.",
#   'score': 0},
#  {'candidate': 'He tries to flee with all of the gold',
#   'reference': "When Spider double-crosses the gang, he tries to flee with all of the gold and is stopped by Ronnie, who is then shot multiple times by Spider's assassins. The group are chased by the assassins and Ronnie and Riya are killed. Spider blows up the location and flees with the gold.",
#   'score': 1},
#  {'candidate': "Spider flees with the gold. Ronnie and Riya are killed by Spider's assassins",
#   'reference': "When Spider double-crosses the gang, he tries to flee with all of the gold and is stopped by Ronnie, who is then shot multiple times by Spider's assassins. The group are chased by the assassins and Ronnie and Riya are killed. Spider blows up the location and flees with the gold.",
#   'score': 1},
#  {'candidate': 'He gets shot',
#   'reference': "When Spider double-crosses the gang, he tries to flee with all of the gold and is stopped by Ronnie, who is then shot multiple times by Spider's assassins. The group are chased by the assassins and Ronnie and Riya are killed. Spider blows up the location and flees with the gold.",
#   'score': 0},
#  {'candidate': 'The train',
#   'reference': 'Sunny is hired to rob a train carrying gold from Russia to Romania.',
#   'score': 1},
#  {'candidate': "Raj's funeral",
#   'reference': 'Sunny is hired to rob a train carrying gold from Russia to Romania.',
#   'score': 0},
#  {'candidate': 'The apartment',
#   'reference': 'Sunny is hired to rob a train carrying gold from Russia to Romania.',
#   'score': 0},
#  {'candidate': 'The Russian mafia',
#   'reference': 'Sunny is hired to rob a train carrying gold from Russia to Romania.',
#   'score': 0},
#  {'candidate': 'It depended on the impulse',
#   'reference': 'Mr. Thorndike acted upon his impulse by commanding his chauffeur to stop at the Court of General Sessions, with the intention of speaking to the district attorney or the judge to try and help young Spear.',
#   'score': 0},
#  {'candidate': "He didn't - he first thought things through",
#   'reference': 'Mr. Thorndike acted upon his impulse by commanding his chauffeur to stop at the Court of General Sessions, with the intention of speaking to the district attorney or the judge to try and help young Spear.',
#   'score': 0},
#  {'candidate': 'All of his friends were called slaves to impulse',
#   'reference': 'Mr. Thorndike acted upon his impulse by commanding his chauffeur to stop at the Court of General Sessions, with the intention of speaking to the district attorney or the judge to try and help young Spear.',
#   'score': 0},
#  {'candidate': 'He tells his chauffeur to go to the Court of General Sessions to say a personal word to the judge',
# ...
#   'score': 1},
#  {'candidate': 'It sinks back down into the mantle',
#   'reference': 'When the mantle material that is near the surface starts to cool, it sinks back down into the mantle, creating deep sea trenches.',
#   'score': 1},
#  {'candidate': 'It continues going toward the surface',
#   'reference': 'When the mantle material that is near the surface starts to cool, it sinks back down into the mantle, creating deep sea trenches.',
#   'score': 0},
#  {'candidate': 'It starts moving horizontally',
#   'reference': 'When the mantle material that is near the surface starts to cool, it sinks back down into the mantle, creating deep sea trenches.',
#   'score': 0},
#  {'candidate': 'It stops',
#   'reference': 'When the mantle material that is near the surface starts to cool, it sinks back down into the mantle, creating deep sea trenches.',
#   'score': 0},
#  {'candidate': 'Convection',
#   'reference': 'Sea trenches occur toward the surface, where the mantle material starts to cool and sink back down into the mantle.',
#   'score': 0},
#  {'candidate': 'On the rocks',
#   'reference': 'Sea trenches occur toward the surface, where the mantle material starts to cool and sink back down into the mantle.',
#   'score': 0},
#  {'candidate': 'Into the mantle',
#   'reference': 'Sea trenches occur toward the surface, where the mantle material starts to cool and sink back down into the mantle.',
#   'score': 0},
#  {'candidate': 'Mantle',
#   'reference': 'Sea trenches occur toward the surface, where the mantle material starts to cool and sink back down into the mantle.',
#   'score': 1},
#  {'candidate': 'Crust',
#   'reference': 'Sea trenches occur toward the surface, where the mantle material starts to cool and sink back down into the mantle.',
#   'score': 0},
#  {'candidate': 'Surface',
#   'reference': 'Sea trenches occur toward the surface, where the mantle material starts to cool and sink back down into the mantle.',
#   'score': 0},
#  {'candidate': 'At the surface because there is more space',
#   'reference': 'At the surface of the Earth.',
#   'score': 0},
#  {'candidate': 'At the Surface',
#   'reference': 'At the surface of the Earth.',
#   'score': 0},
#  {'candidate': 'At its core because it has more heat',
#   'reference': 'At the surface of the Earth.',
#   'score': 1},
#  {'candidate': 'At its core',
#   'reference': 'At the surface of the Earth.',
#   'score': 1},
#  {'candidate': 'The mantle',
#   'reference': "The coolest part of the Earth is the Earth's crust, where the mantle material is mostly stopped and begins to move horizontally.",
#   'score': 0},
#  {'candidate': 'The equator',
#   'reference': "The coolest part of the Earth is the Earth's crust, where the mantle material is mostly stopped and begins to move horizontally.",
#   'score': 0},
#  {'candidate': 'The core',
#   'reference': "The coolest part of the Earth is the Earth's crust, where the mantle material is mostly stopped and begins to move horizontally.",
#   'score': 0},
#  {'candidate': 'The surface',
#   'reference': "The coolest part of the Earth is the Earth's crust, where the mantle material is mostly stopped and begins to move horizontally.",
#   'score': 1},
#  {'candidate': 'The core',
#   'reference': 'The hottest part of the Earth is its core.',
#   'score': 1},
#  {'candidate': 'The Surface',
#   'reference': 'The hottest part of the Earth is its core.',
#   'score': 0},
#  {'candidate': 'Themantle',
#   'reference': 'The hottest part of the Earth is its core.',
#   'score': 0},
#  {'candidate': 'TheEarths core',
#   'reference': 'The hottest part of the Earth is its core.',
#   'score': 1},
#  {'candidate': 'Mantle',
#   'reference': 'The hottest part of the Earth is its core.',
#   'score': 0},
#  {'candidate': 'Because it moves away from the ocean ridge crest',
#   'reference': "The material moves horizontally because it is cooled by the Earth's surface, causing it to sink back down into the mantle.",
#   'score': 0},
#  {'candidate': 'Because it cannot break through the surface',
#   'reference': "The material moves horizontally because it is cooled by the Earth's surface, causing it to sink back down into the mantle.",
#   'score': 1},
#  {'candidate': "It can't break through the surface",
#   'reference': "The material moves horizontally because it is cooled by the Earth's surface, causing it to sink back down into the mantle.",
#   'score': 1},
#  {'candidate': 'Because it is cooler',
#   'reference': "The material moves horizontally because it is cooled by the Earth's surface, causing it to sink back down into the mantle.",
#   'score': 0},
#  {'candidate': 'Because it reaches the core',
#   'reference': "The material moves horizontally because it is cooled by the Earth's surface, causing it to sink back down into the mantle.",
#   'score': 0},
#  {'candidate': 'France', 'reference': 'Menorca', 'score': 0},
#  {'candidate': 'Spain', 'reference': 'Menorca', 'score': 0},
#  {'candidate': 'Mallorca', 'reference': 'Menorca', 'score': 1},
#  {'candidate': 'Trafalgar', 'reference': 'Menorca', 'score': 0},
#  {'candidate': 'Gibraltar', 'reference': 'Menorca', 'score': 0},
#  {'candidate': 'Amiens', 'reference': 'Menorca', 'score': 0},
#  {'candidate': 'kingdom of Aragón', 'reference': 'Menorca', 'score': 0},
#  {'candidate': 'Spain',
#   'reference': 'France marched in to subdue Spain.',
#   'score': 1},
#  {'candidate': 'Trafalgar',
#   'reference': 'France marched in to subdue Spain.',
#   'score': 0},
#  {'candidate': 'Britain',
#   'reference': 'France marched in to subdue Spain.',
#   'score': 0},
#  {'candidate': 'Austria',
#   'reference': 'France marched in to subdue Spain.',
#   'score': 0},
#  {'candidate': 'Britian',
#   'reference': 'France marched in to subdue Spain.',
#   'score': 0},
#  {'candidate': 'Menorca',
#   'reference': 'England clung to Menorca even when Bourbon forces captured Mallorca at the end of the war.',
#   'score': 1},
#  {'candidate': 'the harbor of MahÃ³n (MaÃ³)',
#   'reference': 'England clung to Menorca even when Bourbon forces captured Mallorca at the end of the war.',
#   'score': 1},
#  {'candidate': 'Gibraltar',
#   'reference': 'England clung to Menorca even when Bourbon forces captured Mallorca at the end of the war.',
#   'score': 0},
#  {'candidate': 'Amiens',
#   'reference': 'England clung to Menorca even when Bourbon forces captured Mallorca at the end of the war.',
#   'score': 0},
#  {'candidate': 'Mallorca',
#   'reference': 'England clung to Menorca even when Bourbon forces captured Mallorca at the end of the war.',
#   'score': 0},
#  {'candidate': '2 years', 'reference': 'Thirteen years.', 'score': 1},
#  {'candidate': '13 years', 'reference': 'Thirteen years.', 'score': 0},
#  {'candidate': '114 years', 'reference': 'Thirteen years.', 'score': 0},
#  {'candidate': '108 years', 'reference': 'Thirteen years.', 'score': 0},
#  {'candidate': '13 years', 'reference': 'Thirteen years.', 'score': 0},
#  {'candidate': 'Menorca', 'reference': 'Menorca', 'score': 1},
#  {'candidate': 'Trafalgar', 'reference': 'Menorca', 'score': 0},
#  {'candidate': 'Amiens', 'reference': 'Menorca', 'score': 0},
#  {'candidate': 'Mallorca', 'reference': 'Menorca', 'score': 0},
#  {'candidate': 'MahÃ³n (MaÃ³)', 'reference': 'Menorca', 'score': 0},
#  {'candidate': 'Gibraltar', 'reference': 'Menorca', 'score': 0},
#  {'candidate': '3 years', 'reference': '17 years', 'score': 1},
#  {'candidate': '12 years', 'reference': '17 years', 'score': 0},
#  {'candidate': '9 years', 'reference': '17 years', 'score': 0},
#  {'candidate': '6 years', 'reference': '17 years', 'score': 0},
#  {'candidate': '19th', 'reference': '19th century', 'score': 1},
#  {'candidate': '18th', 'reference': '19th century', 'score': 0},
#  {'candidate': '20th', 'reference': '19th century', 'score': 0},
#  {'candidate': 'Two',
#   'reference': 'Approximately 18 centuries passed between the War of the Spanish Succession and when things began to improve on Mallorca and Menorca.',
#   'score': 1},
#  {'candidate': '4',
#   'reference': 'Approximately 18 centuries passed between the War of the Spanish Succession and when things began to improve on Mallorca and Menorca.',
#   'score': 0},
#  {'candidate': '3',
#   'reference': 'Approximately 18 centuries passed between the War of the Spanish Succession and when things began to improve on Mallorca and Menorca.',
#   'score': 0},
#  {'candidate': 'One',
#   'reference': 'Approximately 18 centuries passed between the War of the Spanish Succession and when things began to improve on Mallorca and Menorca.',
#   'score': 0},
#  {'candidate': 'Abram Gannibal',
#   'reference': 'Yes, Abram Gannibal was the famous great grandfather of Alexander Sergeyevich Pushkin.',
#   'score': 0},
#  {'candidate': 'Maybe',
#   'reference': 'Yes, Abram Gannibal was the famous great grandfather of Alexander Sergeyevich Pushkin.',
#   'score': 0},
#  {'candidate': 'Pushkin',
#   'reference': 'Yes, Abram Gannibal was the famous great grandfather of Alexander Sergeyevich Pushkin.',
#   'score': 0},
#  {'candidate': 'No',
#   'reference': 'Yes, Abram Gannibal was the famous great grandfather of Alexander Sergeyevich Pushkin.',
#   'score': 0},
#  {'candidate': 'Yes',
#   'reference': 'Yes, Abram Gannibal was the famous great grandfather of Alexander Sergeyevich Pushkin.',
#   'score': 1},
#  {'candidate': 'Secret service',
#   'reference': 'Yes, Abram Gannibal was the famous great grandfather of Alexander Sergeyevich Pushkin.',
#   'score': 0},
#  {'candidate': 'Maybe',
#   'reference': "No, Pushkin's descendants were not always wealthy. Pushkin himself was born into Russian nobility in Moscow, but his matrilineal great grandfather was Abram Gannibal, who was brought over as a slave from what is now Cameroon.",
#   'score': 0},
#  {'candidate': 'Chevalier Guard',
#   'reference': "No, Pushkin's descendants were not always wealthy. Pushkin himself was born into Russian nobility in Moscow, but his matrilineal great grandfather was Abram Gannibal, who was brought over as a slave from what is now Cameroon.",
#   'score': 0},
#  {'candidate': 'No',
#   'reference': "No, Pushkin's descendants were not always wealthy. Pushkin himself was born into Russian nobility in Moscow, but his matrilineal great grandfather was Abram Gannibal, who was brought over as a slave from what is now Cameroon.",
#   'score': 0},
#  {'candidate': 'Yes',
#   'reference': "No, Pushkin's descendants were not always wealthy. Pushkin himself was born into Russian nobility in Moscow, but his matrilineal great grandfather was Abram Gannibal, who was brought over as a slave from what is now Cameroon.",
#   'score': 0},
#  {'candidate': 'No, his great grandfather was Abram Gannibal, who was brought over as a slave from what is now Cameroon',
#   'reference': "No, Pushkin's descendants were not always wealthy. Pushkin himself was born into Russian nobility in Moscow, but his matrilineal great grandfather was Abram Gannibal, who was brought over as a slave from what is now Cameroon.",
#   'score': 1},
#  {'candidate': '44',
#   'reference': "Pushkin fought a total of twenty-nine duels after the one he had with the man he accused of seducing Pushkin's wife.",
#   'score': 0},
#  {'candidate': 'None, as he was fatally wounded in that duel',
#   'reference': "Pushkin fought a total of twenty-nine duels after the one he had with the man he accused of seducing Pushkin's wife.",
#   'score': 1},
#  {'candidate': '29',
#   'reference': "Pushkin fought a total of twenty-nine duels after the one he had with the man he accused of seducing Pushkin's wife.",
#   'score': 0},
#  {'candidate': '6',
#   'reference': "Pushkin fought a total of twenty-nine duels after the one he had with the man he accused of seducing Pushkin's wife.",
#   'score': 0},
#  {'candidate': 'Between 26 - 33',
#   'reference': 'Pushkin was 26 years old when his novel in verse, Eugene Onegin, was serialized.',
#   'score': 1},
#  {'candidate': '29 January 1837',
#   'reference': 'Pushkin was 26 years old when his novel in verse, Eugene Onegin, was serialized.',
#   'score': 0},
#  {'candidate': '26',
#   'reference': 'Pushkin was 26 years old when his novel in verse, Eugene Onegin, was serialized.',
#   'score': 0},
#  {'candidate': '18th century',
#   'reference': 'Pushkin was 26 years old when his novel in verse, Eugene Onegin, was serialized.',
#   'score': 0},
#  {'candidate': '24',
#   'reference': 'Pushkin was 26 years old when his novel in verse, Eugene Onegin, was serialized.',
#   'score': 0},
#  {'candidate': '10',
#   'reference': 'Pushkin was 26 years old when his novel in verse, Eugene Onegin, was serialized.',
#   'score': 0},
#  {'candidate': 'Born in a noble family but matrilineal descent is as slave',
#   'reference': 'Pushkin was born into Russian nobility in Moscow, but his matrilineal great grandfather was Abram Gannibal, who was brought over as a slave from what is now Cameroon, making Pushkin of both noble and non-noble descent.',
#   'score': 1},
#  {'candidate': 'Pushkin was born into Russian nobility in Moscow',
#   'reference': 'Pushkin was born into Russian nobility in Moscow, but his matrilineal great grandfather was Abram Gannibal, who was brought over as a slave from what is now Cameroon, making Pushkin of both noble and non-noble descent.',
#   'score': 1},
#  {'candidate': 'The founder of modern Russian literature',
#   'reference': 'Pushkin was born into Russian nobility in Moscow, but his matrilineal great grandfather was Abram Gannibal, who was brought over as a slave from what is now Cameroon, making Pushkin of both noble and non-noble descent.',
#   'score': 0},
#  {'candidate': 'He was born into nobility but his maternal great-grandfather was a slave from Cameroon',
#   'reference': 'Pushkin was born into Russian nobility in Moscow, but his matrilineal great grandfather was Abram Gannibal, who was brought over as a slave from what is now Cameroon, making Pushkin of both noble and non-noble descent.',
#   'score': 1},
#  {'candidate': "Under the strict surveillance of the Tsar's political police",
#   'reference': 'Pushkin was born into Russian nobility in Moscow, but his matrilineal great grandfather was Abram Gannibal, who was brought over as a slave from what is now Cameroon, making Pushkin of both noble and non-noble descent.',
#   'score': 0},
#  {'candidate': 'Great grandfather was Abram Gannibal was a slave',
#   'reference': 'Pushkin was born into Russian nobility in Moscow, but his matrilineal great grandfather was Abram Gannibal, who was brought over as a slave from what is now Cameroon, making Pushkin of both noble and non-noble descent.',
#   'score': 1},
#  {'candidate': '15',
#   'reference': 'Pushkin began to serialize Eugene Onegin at the age of 26.',
#   'score': 0},
#  {'candidate': '29',
#   'reference': 'Pushkin began to serialize Eugene Onegin at the age of 26.',
#   'score': 0},
#  {'candidate': 'He began to serialize it when he was 26 years old',
#   'reference': 'Pushkin began to serialize Eugene Onegin at the age of 26.',
#   'score': 1},
#  {'candidate': '15',
#   'reference': 'Pushkin was 26 years old when Eugene Onegin began serialization.',
#   'score': 0},
#  {'candidate': '26',
#   'reference': 'Pushkin was 26 years old when Eugene Onegin began serialization.',
#   'score': 1},
#  {'candidate': '29',
#   'reference': 'Pushkin was 26 years old when Eugene Onegin began serialization.',
#   'score': 0},
#  {'candidate': 'Tsarskoye Selo Lyceum',
#   'reference': "Pushkin killed Georges-Charles de Heeckeren d'Anthes when fending off his wife's would be seducer.",
#   'score': 0},
#  {'candidate': "Georges-Charles de Heeckeren d'Anthes",
#   'reference': "Pushkin killed Georges-Charles de Heeckeren d'Anthes when fending off his wife's would be seducer.",
#   'score': 1},
#  {'candidate': 'Vowing',
#   'reference': "Pushkin killed Georges-Charles de Heeckeren d'Anthes when fending off his wife's would be seducer.",
#   'score': 0},
#  {'candidate': '15',
#   'reference': 'Pushkin was 26 years old the first year his novel, Eugene Onegin, was serialized.',
#   'score': 0},
#  {'candidate': 'Twenty-six years of age',
#   'reference': 'Pushkin was 26 years old the first year his novel, Eugene Onegin, was serialized.',
#   'score': 1},
#  {'candidate': '29',
#   'reference': 'Pushkin was 26 years old the first year his novel, Eugene Onegin, was serialized.',
#   'score': 0},
#  ...]
