# %% [markdown]
# # Train ModernBERT on Pseudo-labeled Data
#
# Pseudo-labeled data comes from two sources:
# - MultiRC, pseudo-labeled by GPT5
# - Authentic iTELL data, pseudo-labeled by o3-mini
#
# Humans have labeled a non-overlapping portion of the authentic iTELL data. This will be our held-out test set.

# %%
import os
from pathlib import Path

import numpy as np
import pandas as pd
import torch
import datasets
from transformers import (
    Trainer,
    TrainingArguments,
    DataCollatorWithPadding,
    AutoTokenizer,
    AutoModelForSequenceClassification,
)
from sklearn import metrics
from scipy import stats

torch.set_float32_matmul_precision("high")
os.environ["TOKENIZERS_PARALLELISM"] = "true"

# %%
model_name_or_path = "answerdotai/ModernBERT-base"
output_dir = "../../results/modernbert-multirc-pseudo-labeled"

# Training/Validation Data:
datadict_path = "../../data/authentic-gpt5-scores-multirc-gpt5-scores.hf"  # The prepared training and validation data
multirc_path = "../../data/multirc-data-w-gpt5-scores-v2.csv"  # A subsample of MultiRC, scored by GPT 5 with accuracy label
authentic_path = "../../data/authentic_train_data_v2.csv"  # Authentic data from iTELL, scored by GPT 5 with reference answer

# Test Data:
test_data_path = "../../data/authentic_test_data_v2.csv"  # Authentic data from iTELL, scored by the iTELL development team

batch_size = 4
num_epochs = 6
learning_rate = 1e-5
seed = 42

tokenizer = AutoTokenizer.from_pretrained(model_name_or_path)

# %% [markdown]
# ## Construct Dataset

# %%
pd.read_csv(test_data_path)
# Out:
#                                               response  ensemble_score  \
# 0                                             learning               0
# 1                                               answer               0
# 2    human observers made live annotations regardin...               0
# 3    Recorded data from student while doing help ba...               0
# 4                                    analyzing context               0
# ..                                                 ...             ...
# 485                 goal, inteded users, visualization               1
# 486  What is the goal of the visualization? What qu...               2
# 487  The questions that need to be answered during ...               2
# 488  Understanding the area of the problem and the ...               2
# 489  Because they serve no purpose other than to ma...               1
#
#                         user_id            page_slug  \
# 0     clu91tykw0002l00fz3o1vfsh            emotional
# 1     cluc0hclp0000ju0flnuywkrr            emotional
# 2     clu7cooq9000kjt0fbxh29vfy            emotional
# 3     clucz38h40005jv0fhc5vjpfp            emotional
# 4     clu8uwkw20000jz0f4yyg6c1d            emotional
# ..                          ...                  ...
# 485   clubevuw60000lb0fo8o6iojh        learning-an-1
# 486   clu7c03g40000jt0f4ee1iohe        learning-an-1
# 487   clua4ou3q0000l10g63l2l5mu        learning-an-1
# 488   cludb8xlt0011l60ft7jzzg85        learning-an-1
# 489  fvbptwwe5elyvsqwx7cqgxs5fa  2-program-structure
#
#                                             chunk_slug  \
# 0    01-Affect-Detection-from-Student-Activity-Data...
# 1    01-Affect-Detection-from-Student-Activity-Data...
# 2    01-Affect-Detection-from-Student-Activity-Data...
# 3    01-Affect-Detection-from-Student-Activity-Data...
# 4    01-Affect-Detection-from-Student-Activity-Data...
# ..                                                 ...
# 485                            How-to-Get-Started-474t
# 486                            How-to-Get-Started-474t
# 487                            How-to-Get-Started-474t
# 488                            How-to-Get-Started-474t
# 489                                Indenting-Code-784t
#
#                         created_at          volume_slug  \
# 0          2024-04-15 19:57:38.656              cornell
# 1           2024-05-05 20:29:28.14              cornell
# 2          2024-04-15 19:03:37.985              cornell
# 3          2024-03-30 01:56:12.488              cornell
# 4          2024-05-03 20:56:52.298              cornell
# ..                             ...                  ...
# 485        2024-03-30 01:50:34.917              cornell
# 486        2024-04-16 19:19:27.571              cornell
# 487        2024-04-21 14:19:58.873              cornell
# 488        2024-04-28 03:01:25.439              cornell
# 489  2024-08-29 16:50:43.392008+00  eloquent-javascript
#
#                        volume_title                    page_title  \
# 0    Handbook of Learning Analytics  Emotional Learning Analytics
# 1    Handbook of Learning Analytics  Emotional Learning Analytics
# 2    Handbook of Learning Analytics  Emotional Learning Analytics
# 3    Handbook of Learning Analytics  Emotional Learning Analytics
# 4    Handbook of Learning Analytics  Emotional Learning Analytics
# ..                              ...                           ...
# 485  Handbook of Learning Analytics  Learning Analytics Dashboard
# 486  Handbook of Learning Analytics  Learning Analytics Dashboard
# 487  Handbook of Learning Analytics  Learning Analytics Dashboard
# 488  Handbook of Learning Analytics  Learning Analytics Dashboard
# 489             Eloquent JavaScript          2. Program Structure
#
#                                         chunk_header  \
# 0    0.1 Affect Detection from Student Activity Data
# 1    0.1 Affect Detection from Student Activity Data
# 2    0.1 Affect Detection from Student Activity Data
# 3    0.1 Affect Detection from Student Activity Data
# 4    0.1 Affect Detection from Student Activity Data
# ..                                               ...
# 485                               How to Get Started
# 486                               How to Get Started
# 487                               How to Get Started
# 488                               How to Get Started
# 489                                   Indenting Code
#
#                                             chunk_text  \
# 0    Affective states cannot be directly measured b...
# 1    Affective states cannot be directly measured b...
# 2    Affective states cannot be directly measured b...
# 3    Affective states cannot be directly measured b...
# 4    Affective states cannot be directly measured b...
# ..                                                 ...
# 485  To leverage the advanced perceptual abilities ...
# 486  To leverage the advanced perceptual abilities ...
# 487  To leverage the advanced perceptual abilities ...
# 488  To leverage the advanced perceptual abilities ...
# 489  In the examples, I’ve been adding spaces in fr...
#
#                                               question  \
# 0    What approach was used to infer affect by anal...
# 1    What approach was used to infer affect by anal...
# 2    What approach was used to infer affect by anal...
# 3    What approach was used to infer affect by anal...
# 4    What approach was used to infer affect by anal...
# ..                                                 ...
# 485  What questions need to be answered during the ...
# 486  What questions need to be answered during the ...
# 487  What questions need to be answered during the ...
# 488  What questions need to be answered during the ...
# 489  Why are spaces and line breaks not required in...
#
#                                                 answer  gpt5_score  \
# 0    The interaction-based, log-file based, or sens...           2
# 1    The interaction-based, log-file based, or sens...           1
# 2    The interaction-based, log-file based, or sens...           2
# 3    The interaction-based, log-file based, or sens...           2
# 4    The interaction-based, log-file based, or sens...           2
# ..                                                 ...         ...
# 485  Questions about the goal of the visualization,...           2
# 486  Questions about the goal of the visualization,...           3
# 487  Questions about the goal of the visualization,...           4
# 488  Questions about the goal of the visualization,...           2
# 489  Spaces and line breaks are not required in pro...           4
#
#      human_score annotator
# 0            1.0   langdon
# 1            1.0   langdon
# 2            3.0   langdon
# 3            3.0   langdon
# 4            2.0   langdon
# ..           ...       ...
# 485          3.0     Saeyi
# 486          3.0     Saeyi
# 487          4.0     Saeyi
# 488          3.0     Saeyi
# 489          3.0     Saeyi
#
# [490 rows x 16 columns]

# %%
train_dev_df1 = pd.read_csv(multirc_path)[
    ["chunk_text", "question", "response", "gpt5_score"]
].rename(columns={"gpt5_score": "label"})
train_dev_df2 = pd.read_csv(authentic_path)[
    ["chunk_text", "question", "response", "gpt5_score", "answer"]
].rename(columns={"gpt5_score": "label"})
test_df = pd.read_csv(test_data_path)[
    ["chunk_text", "question", "response", "human_score", "answer"]
].rename(columns={"human_score": "label"})

train_dev_df = pd.concat([train_dev_df1, train_dev_df2])
train_dev_df
# Out:
#                                             chunk_text  \
# 0    A flood occurs when a river overflows its bank...
# 1    Force is a vector. What then is a vector? Thin...
# 2    Madrid, Spain (CNN) -- Relatives of a woman ki...
# 3    Flowing water causes sediment to move. Flowing...
# 4    How would the universe look without gravity? I...
# ..                                                 ...
# 933  Let’s begin with a brief overview of spectacul...
# 934  Let’s begin with a brief overview of spectacul...
# 935  Let’s begin with a brief overview of spectacul...
# 936  Let’s begin with a brief overview of spectacul...
# 937  Consider a program that outputs all even numbe...
#
#                                               question  \
# 0    What forms the raised strip near the edge of a...
# 1    What two pieces of information does a vector p...
# 2    Where was the Spanish MD82 bound for when the ...
# 3    How long does it take for water to dissolve ro...
# 4         How would the universe look without gravity?
# ..                                                 ...
# 933    What were economic conditions like before 1870?
# 934    What were economic conditions like before 1870?
# 935    What were economic conditions like before 1870?
# 936    What were economic conditions like before 1870?
# 937    What is the purpose of a do loop in JavaScript?
#
#                                               response  label  \
# 0                                         Sandy desert      2
# 1                                  Motion and distance      2
# 2                                    Spain's Barcelona      1
# 3                                            Few  days      1
# 4                                           No planets      3
# ..                                                 ...    ...
# 933  Slow technological progress, natural disasters...      3
# 934  Economic conditions before 1870 were sluggish ...      3
# 935                      economic conditions were slow      2
# 936  Before 1870, economic conditions were relative...      4
# 937  The purpose of a "do . . . while " loop in Jav...      4
#
#                                                 answer
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 933  Economic conditions before 1870 were marked by...
# 934  Economic conditions before 1870 were marked by...
# 935  Economic conditions before 1870 were marked by...
# 936  Economic conditions before 1870 were marked by...
# 937  A do loop always executes its body at least on...
#
# [6191 rows x 5 columns]

# %%
train_dev_ds = datasets.Dataset.from_pandas(train_dev_df, preserve_index=False)
dd = train_dev_ds.train_test_split(test_size=0.10, seed=42)
dd["dev"] = dd["test"]

test_ds = datasets.Dataset.from_pandas(test_df, preserve_index=False)
dd["test"] = test_ds
dd
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['chunk_text', 'question', 'response', 'label', 'answer'],
#         num_rows: 5571
#     })
#     test: Dataset({
#         features: ['chunk_text', 'question', 'response', 'label', 'answer'],
#         num_rows: 490
#     })
#     dev: Dataset({
#         features: ['chunk_text', 'question', 'response', 'label', 'answer'],
#         num_rows: 620
#     })
# })

# %%
dd.save_to_disk(datadict_path)
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/5571 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/490 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/620 [00:00<?, ? examples/s]

# %% [markdown]
# ## Prepare Dataset

# %%
dd = datasets.DatasetDict.load_from_disk(datadict_path)


def preprocess_function(example):
    input_str = "\n\n\n".join(
        [
            f"Passage: {example['chunk_text']}",
            f"Question: {example['question']}",
            f"Reference Answer: {example.get('answer', '')}",
            f"Student Response: {example['response']}",
        ]
    )
    new_example = tokenizer(input_str)
    return tokenizer(input_str)


dd = dd.map(
    preprocess_function,
    batched=False,
    remove_columns=[
        "chunk_text",
        "question",
        "response",
        "answer",
    ],
)

# Convert label column to float type
new_features = dd["train"].features.copy()
new_features["label"] = datasets.Value("float32")
dd = dd.cast(new_features)
dd
# Out:
# Map:   0%|          | 0/5571 [00:00<?, ? examples/s]
# Map:   0%|          | 0/490 [00:00<?, ? examples/s]
# Map:   0%|          | 0/620 [00:00<?, ? examples/s]
# Casting the dataset:   0%|          | 0/5571 [00:00<?, ? examples/s]
# Casting the dataset:   0%|          | 0/490 [00:00<?, ? examples/s]
# Casting the dataset:   0%|          | 0/620 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['label', 'input_ids', 'attention_mask'],
#         num_rows: 5571
#     })
#     test: Dataset({
#         features: ['label', 'input_ids', 'attention_mask'],
#         num_rows: 490
#     })
#     dev: Dataset({
#         features: ['label', 'input_ids', 'attention_mask'],
#         num_rows: 620
#     })
# })

# %% [markdown]
# ## Set Up Training

# %%
def model_init():
    model = AutoModelForSequenceClassification.from_pretrained(
        model_name_or_path,
        num_labels=1,
    )
    return model

# %%
def compute_metrics(eval_pred):
    """
    eval_pred : tuple
        A tuple of (logits, labels) provided by the Hugging Face Trainer.
        - logits: numpy array of shape (n_samples,) for binary classification
        - labels: numpy array of shape (n_samples,)
    """
    preds, labels = eval_pred

    metric_dict = {}

    # Regression metrics
    metric_dict["mse"] = metrics.mean_squared_error(labels, preds)
    metric_dict["rmse"] = metrics.mean_squared_error(labels, preds, squared=False)
    metric_dict["mae"] = metrics.mean_absolute_error(labels, preds)
    metric_dict["r2"] = metrics.r2_score(labels, preds)

    # Classification metrics (round to integers for ordinal ratings)
    preds_int = np.round(preds).astype(int)
    labels_int = np.round(labels).astype(int)

    # Quadratic Weighted Kappa
    metric_dict["qwk"] = metrics.cohen_kappa_score(
        labels_int, preds_int, weights="quadratic"
    )

    # Spearman's r
    metric_dict["spearman"] = stats.spearmanr(labels_int, preds_int).statistic

    return metric_dict

# %%
data_collator = DataCollatorWithPadding(tokenizer=tokenizer, padding="longest")

# %%
training_args = TrainingArguments(
    output_dir=output_dir,
    bf16=True,  # bfloat16 training
    optim="adamw_torch_fused",
    num_train_epochs=num_epochs,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    learning_rate=learning_rate,
    logging_dir="../../logs",
    eval_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    seed=seed,
    log_level="error",
    disable_tqdm=False,
    report_to="none",  # Disable WandB reporting
)

trainer = Trainer(
    model_init=model_init,
    args=training_args,
    data_collator=data_collator,
    train_dataset=dd["train"],
    eval_dataset=dd["dev"],
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
#     <div>
#
#       <progress value='8358' max='8358' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [8358/8358 21:51, Epoch 6/6]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Mse</th>
#       <th>Rmse</th>
#       <th>Mae</th>
#       <th>R2</th>
#       <th>Qwk</th>
#       <th>Spearman</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.741000</td>
#       <td>0.640259</td>
#       <td>0.640259</td>
#       <td>0.800162</td>
#       <td>0.651172</td>
#       <td>0.313698</td>
#       <td>0.450754</td>
#       <td>0.473545</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.564600</td>
#       <td>0.595007</td>
#       <td>0.595007</td>
#       <td>0.771367</td>
#       <td>0.613483</td>
#       <td>0.362203</td>
#       <td>0.610933</td>
#       <td>0.609724</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.463300</td>
#       <td>0.556508</td>
#       <td>0.556508</td>
#       <td>0.745995</td>
#       <td>0.612979</td>
#       <td>0.403472</td>
#       <td>0.564224</td>
#       <td>0.573342</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.375400</td>
#       <td>0.549990</td>
#       <td>0.549990</td>
#       <td>0.741613</td>
#       <td>0.598009</td>
#       <td>0.410458</td>
#       <td>0.607821</td>
#       <td>0.596907</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.280900</td>
#       <td>0.558010</td>
#       <td>0.558010</td>
#       <td>0.747001</td>
#       <td>0.580544</td>
#       <td>0.401862</td>
#       <td>0.621801</td>
#       <td>0.607094</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.211800</td>
#       <td>0.561813</td>
#       <td>0.561813</td>
#       <td>0.749542</td>
#       <td>0.578478</td>
#       <td>0.397785</td>
#       <td>0.630362</td>
#       <td>0.613691</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=8358, training_loss=0.45578239260178544, metrics={'train_runtime': 1325.0731, 'train_samples_per_second': 25.226, 'train_steps_per_second': 6.308, 'total_flos': 1.3437371708316852e+16, 'train_loss': 0.45578239260178544, 'epoch': 6.0})

# %%
trainer.save_model(
    "../../results/modernbert_authentic_multirc_with_reference_with_label"
)

# %% [markdown]
# ## Functionality Test

# %%
from transformers import pipeline

classifier = pipeline(
    task="text-classification",
    model="../../results/modernbert_authentic_multirc_with_reference_with_label",
    tokenizer=model_name_or_path,
    device=0,
)

sample = "Smoking is bad for your health."

classifier(sample)
# Out:
# [{'label': 'LABEL_0', 'score': 1.8519365787506104}]
