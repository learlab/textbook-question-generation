# %% [markdown]
# # Train ModernBERT on Pseudo-labeled Data
#
# Pseudo-labeled data comes from two sources:
# - MultiRC, pseudo-labeled by GPT5
# - Authentic iTELL data, pseudo-labeled by o3-mini
#
# Humans have labeled a non-overlapping portion of the authentic iTELL data. This will be our held-out test set.

# %%
import os
from pathlib import Path

import numpy as np
import pandas as pd
import torch
import datasets
from transformers import (
    Trainer,
    TrainingArguments,
    DataCollatorWithPadding,
    AutoTokenizer,
    AutoModelForSequenceClassification,
)
from sklearn import metrics
from scipy import stats

torch.set_float32_matmul_precision("high")
os.environ["TOKENIZERS_PARALLELISM"] = "true"

# %%
model_name_or_path = "answerdotai/ModernBERT-base"
output_dir = "../../results/modernbert-multirc-pseudo-labeled"

# Training/Validation Data:
datadict_path = "../../data/authentic-03-scores-multirc-gpt5-scores.hf"  # The prepared training and validation data
multirc_path = "../../data/multirc-data-w-gpt5-scores.csv"  # A subsample of MultiRC, scored by GPT 5
authentic_path = "../../data/authentic_train_data.csv"  # Authentic data from iTELL, scored by o3-mini using the same rubric/prompt

# Test Data:
test_data_path = "../../data/authentic_test_data.csv"  # Authentic data from iTELL, scored by the iTELL development team

batch_size = 4
num_epochs = 6
learning_rate = 1e-5
seed = 42

tokenizer = AutoTokenizer.from_pretrained(model_name_or_path)

# %% [markdown]
# ## Construct Dataset

# %%
pd.read_csv(test_data_path)
# Out:
#                                               response  ensemble_score  \
# 0                                             learning               0
# 1                                               answer               0
# 2    human observers made live annotations regardin...               0
# 3    Recorded data from student while doing help ba...               0
# 4                                    analyzing context               0
# ..                                                 ...             ...
# 365  trace refer to ambient data generated by learn...               2
# 366  They are ambient data generated when learners ...               2
# 367  to make bindings in one module accessible in o...               1
# 368  It is used to make function, class, object, or...               2
# 369  contributory negligence or comparative neglige...               2
#
#                         user_id  \
# 0     clu91tykw0002l00fz3o1vfsh
# 1     cluc0hclp0000ju0flnuywkrr
# 2     clu7cooq9000kjt0fbxh29vfy
# 3     clucz38h40005jv0fhc5vjpfp
# 4     clu8uwkw20000jz0f4yyg6c1d
# ..                          ...
# 365   clu7s2zh60005jt0gpk3z8at5
# 366   clu8s7sxo0005l50ft5mjtbjd
# 367  fvbptwwe5elyvsqwx7cqgxs5fa
# 368  c35eotu6a3guavdkekjwe3346i
# 369   clra4r5n60007jv0fsamq7mmz
#
#                                           page_slug  \
# 0                                         emotional
# 1                                         emotional
# 2                                         emotional
# 3                                         emotional
# 4                                         emotional
# ..                                              ...
# 365  learning-analytics-for-self-regulated-learning
# 366  learning-analytics-for-self-regulated-learning
# 367                                      10-modules
# 368                                      10-modules
# 369                                    negligence-2
#
#                                             chunk_slug  \
# 0    01-Affect-Detection-from-Student-Activity-Data...
# 1    01-Affect-Detection-from-Student-Activity-Data...
# 2    01-Affect-Detection-from-Student-Activity-Data...
# 3    01-Affect-Detection-from-Student-Activity-Data...
# 4    01-Affect-Detection-from-Student-Activity-Data...
# ..                                                 ...
# 365  Data-For-Learning-Analytics-About-Learning-And...
# 366  Data-For-Learning-Analytics-About-Learning-And...
# 367                                    ES-modules-845t
# 368                                    ES-modules-845t
# 369                                        Excuses-90t
#
#                         created_at                             volume_slug  \
# 0          2024-04-15 19:57:38.656                                 cornell
# 1           2024-05-05 20:29:28.14                                 cornell
# 2          2024-04-15 19:03:37.985                                 cornell
# 3          2024-03-30 01:56:12.488                                 cornell
# 4          2024-05-03 20:56:52.298                                 cornell
# ..                             ...                                     ...
# 365        2024-04-20 06:30:33.256                                 cornell
# 366        2024-03-27 15:29:40.613                                 cornell
# 367  2024-09-11 16:04:14.815953+00                     eloquent-javascript
# 368  2024-09-10 19:11:56.866991+00                     eloquent-javascript
# 369        2024-02-25 22:27:48.867  business-law-and-the-legal-environment
#
#                                volume_title  \
# 0            Handbook of Learning Analytics
# 1            Handbook of Learning Analytics
# 2            Handbook of Learning Analytics
# 3            Handbook of Learning Analytics
# 4            Handbook of Learning Analytics
# ..                                      ...
# 365          Handbook of Learning Analytics
# 366          Handbook of Learning Analytics
# 367                     Eloquent JavaScript
# 368                     Eloquent JavaScript
# 369  Business Law and the Legal Environment
#
#                                          page_title  \
# 0                      Emotional Learning Analytics
# 1                      Emotional Learning Analytics
# 2                      Emotional Learning Analytics
# 3                      Emotional Learning Analytics
# 4                      Emotional Learning Analytics
# ..                                              ...
# 365  Learning Analytics for Self-Regulated Learning
# 366  Learning Analytics for Self-Regulated Learning
# 367                                     10. Modules
# 368                                     10. Modules
# 369                                      Negligence
#
#                                           chunk_header  \
# 0      0.1 Affect Detection from Student Activity Data
# 1      0.1 Affect Detection from Student Activity Data
# 2      0.1 Affect Detection from Student Activity Data
# 3      0.1 Affect Detection from Student Activity Data
# 4      0.1 Affect Detection from Student Activity Data
# ..                                                 ...
# 365  Data For Learning Analytics About Learning And...
# 366  Data For Learning Analytics About Learning And...
# 367                                         ES modules
# 368                                         ES modules
# 369                                            Excuses
#
#                                             chunk_text  \
# 0    Affective states cannot be directly measured b...
# 1    Affective states cannot be directly measured b...
# 2    Affective states cannot be directly measured b...
# 3    Affective states cannot be directly measured b...
# 4    Affective states cannot be directly measured b...
# ..                                                 ...
# 365  Traces\n\nAs learners work, they generate ambi...
# 366  Traces\n\nAs learners work, they generate ambi...
# 367  The original JavaScript language did not have ...
# 368  The original JavaScript language did not have ...
# 369  There are more excuses (defenses) than are lis...
#
#                                               question  \
# 0    What approach was used to infer affect by anal...
# 1    What approach was used to infer affect by anal...
# 2    What approach was used to infer affect by anal...
# 3    What approach was used to infer affect by anal...
# 4    What approach was used to infer affect by anal...
# ..                                                 ...
# 365  What are traces and what do they reveal about ...
# 366  What are traces and what do they reveal about ...
# 367  What is the purpose of the export keyword in J...
# 368  What is the purpose of the export keyword in J...
# 369  What are some of the principal defenses that c...
#
#                                                 answer  o3_mini_score  \
# 0    The interaction-based, log-file based, or sens...              1
# 1    The interaction-based, log-file based, or sens...              1
# 2    The interaction-based, log-file based, or sens...              2
# 3    The interaction-based, log-file based, or sens...              2
# 4    The interaction-based, log-file based, or sens...              2
# ..                                                 ...            ...
# 365  Traces are ambient data generated by learners ...              4
# 366  Traces are ambient data generated by learners ...              3
# 367  The export keyword is used to indicate that a ...              3
# 368  The export keyword is used to indicate that a ...              4
# 369  Contributory negligence or comparative neglige...              4
#
#      human_score annotator
# 0            1.0   langdon
# 1            1.0   langdon
# 2            3.0   langdon
# 3            3.0   langdon
# 4            2.0   langdon
# ..           ...       ...
# 365          4.0   Tobasum
# 366          2.0   Tobasum
# 367          3.0   Tobasum
# 368          4.0   Tobasum
# 369          4.0   Tobasum
#
# [370 rows x 16 columns]

# %%
train_dev_df1 = pd.read_csv(multirc_path)[
    ["chunk_text", "question", "response", "gpt5_score"]
].rename(columns={"gpt5_score": "label"})
train_dev_df2 = pd.read_csv(authentic_path)[
    ["chunk_text", "question", "response", "o3_mini_score", "answer"]
].rename(columns={"o3_mini_score": "label"})
test_df = pd.read_csv(test_data_path)[
    ["chunk_text", "question", "response", "human_score", "answer"]
].rename(columns={"human_score": "label"})

train_dev_df = pd.concat([train_dev_df1, train_dev_df2])
train_dev_df
# Out:
#                                              chunk_text  \
# 0     A flood occurs when a river overflows its bank...
# 1     Force is a vector. What then is a vector? Thin...
# 2     Madrid, Spain (CNN) -- Relatives of a woman ki...
# 3     Flowing water causes sediment to move. Flowing...
# 4     How would the universe look without gravity? I...
# ...                                                 ...
# 1053  Let’s begin with a brief overview of spectacul...
# 1054  Let’s begin with a brief overview of spectacul...
# 1055  Let’s begin with a brief overview of spectacul...
# 1056  Let’s begin with a brief overview of spectacul...
# 1057  Consider a program that outputs all even numbe...
#
#                                                question  \
# 0     What forms the raised strip near the edge of a...
# 1     What two pieces of information does a vector p...
# 2     Where was the Spanish MD82 bound for when the ...
# 3     How long does it take for water to dissolve ro...
# 4          How would the universe look without gravity?
# ...                                                 ...
# 1053    What were economic conditions like before 1870?
# 1054    What were economic conditions like before 1870?
# 1055    What were economic conditions like before 1870?
# 1056    What were economic conditions like before 1870?
# 1057    What is the purpose of a do loop in JavaScript?
#
#                                                response  label  \
# 0                                          Sandy desert      1
# 1                                   Motion and distance      2
# 2                                     Spain's Barcelona      1
# 3                                             Few  days      1
# 4                                            No planets      2
# ...                                                 ...    ...
# 1053  Slow technological progress, natural disasters...      4
# 1054  Economic conditions before 1870 were sluggish ...      2
# 1055                      economic conditions were slow      2
# 1056  Before 1870, economic conditions were relative...      2
# 1057  The purpose of a "do . . . while " loop in Jav...      4
#
#                                                  answer
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1053  Economic conditions before 1870 were marked by...
# 1054  Economic conditions before 1870 were marked by...
# 1055  Economic conditions before 1870 were marked by...
# 1056  Economic conditions before 1870 were marked by...
# 1057  A do loop always executes its body at least on...
#
# [5560 rows x 5 columns]

# %%
train_dev_ds = datasets.Dataset.from_pandas(train_dev_df, preserve_index=False)
dd = train_dev_ds.train_test_split(test_size=0.10, seed=42)
dd["dev"] = dd["test"]

test_ds = datasets.Dataset.from_pandas(test_df, preserve_index=False)
dd["test"] = test_ds
dd
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['chunk_text', 'question', 'response', 'label', 'answer'],
#         num_rows: 5004
#     })
#     test: Dataset({
#         features: ['chunk_text', 'question', 'response', 'label', 'answer'],
#         num_rows: 370
#     })
#     dev: Dataset({
#         features: ['chunk_text', 'question', 'response', 'label', 'answer'],
#         num_rows: 556
#     })
# })

# %%
dd.save_to_disk(datadict_path)
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/5004 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/370 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/556 [00:00<?, ? examples/s]

# %% [markdown]
# ## Prepare Dataset

# %%
dd = datasets.DatasetDict.load_from_disk(datadict_path)


def preprocess_function(example):
    input_str = "\n\n\n".join(
        [
            f"Passage: {example['chunk_text']}",
            f"Question: {example['question']}",
            f"Reference Answer: {example.get('answer', '')}",
            f"Student Response: {example['response']}",
        ]
    )
    new_example = tokenizer(input_str)
    return tokenizer(input_str)


dd = dd.map(
    preprocess_function,
    batched=False,
    remove_columns=[
        "chunk_text",
        "question",
        "response",
        "answer",
    ],
)

# Convert label column to float type
new_features = dd["train"].features.copy()
new_features["label"] = datasets.Value("float32")
dd = dd.cast(new_features)
dd
# Out:
# Casting the dataset:   0%|          | 0/5004 [00:00<?, ? examples/s]
# Casting the dataset:   0%|          | 0/370 [00:00<?, ? examples/s]
# Casting the dataset:   0%|          | 0/556 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['label', 'input_ids', 'attention_mask'],
#         num_rows: 5004
#     })
#     test: Dataset({
#         features: ['label', 'input_ids', 'attention_mask'],
#         num_rows: 370
#     })
#     dev: Dataset({
#         features: ['label', 'input_ids', 'attention_mask'],
#         num_rows: 556
#     })
# })

# %% [markdown]
# ## Set Up Training

# %%
def model_init():
    model = AutoModelForSequenceClassification.from_pretrained(
        model_name_or_path,
        num_labels=1,
    )
    return model

# %%
def compute_metrics(eval_pred):
    """
    eval_pred : tuple
        A tuple of (logits, labels) provided by the Hugging Face Trainer.
        - logits: numpy array of shape (n_samples,) for binary classification
        - labels: numpy array of shape (n_samples,)
    """
    preds, labels = eval_pred

    metric_dict = {}

    # Regression metrics
    metric_dict["mse"] = metrics.mean_squared_error(labels, preds)
    metric_dict["rmse"] = metrics.mean_squared_error(labels, preds, squared=False)
    metric_dict["mae"] = metrics.mean_absolute_error(labels, preds)
    metric_dict["r2"] = metrics.r2_score(labels, preds)

    # Classification metrics (round to integers for ordinal ratings)
    preds_int = np.round(preds).astype(int)
    labels_int = np.round(labels).astype(int)

    # Quadratic Weighted Kappa
    metric_dict["qwk"] = metrics.cohen_kappa_score(
        labels_int, preds_int, weights="quadratic"
    )

    # Spearman's r
    metric_dict["spearman"] = stats.spearmanr(labels_int, preds_int).statistic

    return metric_dict

# %%
data_collator = DataCollatorWithPadding(tokenizer=tokenizer, padding="longest")

# %%
training_args = TrainingArguments(
    output_dir=output_dir,
    bf16=True,  # bfloat16 training
    optim="adamw_torch_fused",
    num_train_epochs=num_epochs,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    learning_rate=learning_rate,
    logging_dir="../../logs",
    eval_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    seed=seed,
    log_level="error",
    disable_tqdm=False,
    report_to="none",  # Disable WandB reporting
)

trainer = Trainer(
    model_init=model_init,
    args=training_args,
    data_collator=data_collator,
    train_dataset=dd["train"],
    eval_dataset=dd["dev"],
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
#     <div>
#
#       <progress value='7506' max='7506' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [7506/7506 17:01, Epoch 6/6]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Mse</th>
#       <th>Rmse</th>
#       <th>Mae</th>
#       <th>R2</th>
#       <th>Qwk</th>
#       <th>Spearman</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.805300</td>
#       <td>0.742637</td>
#       <td>0.742637</td>
#       <td>0.861764</td>
#       <td>0.736581</td>
#       <td>0.252449</td>
#       <td>0.316983</td>
#       <td>0.420148</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.657200</td>
#       <td>0.696517</td>
#       <td>0.696517</td>
#       <td>0.834576</td>
#       <td>0.689032</td>
#       <td>0.298874</td>
#       <td>0.430365</td>
#       <td>0.506370</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.573300</td>
#       <td>0.775656</td>
#       <td>0.775656</td>
#       <td>0.880713</td>
#       <td>0.671910</td>
#       <td>0.219212</td>
#       <td>0.564980</td>
#       <td>0.553641</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.496400</td>
#       <td>0.635834</td>
#       <td>0.635834</td>
#       <td>0.797392</td>
#       <td>0.642564</td>
#       <td>0.359959</td>
#       <td>0.565201</td>
#       <td>0.569532</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.366000</td>
#       <td>0.696630</td>
#       <td>0.696630</td>
#       <td>0.834644</td>
#       <td>0.646625</td>
#       <td>0.298761</td>
#       <td>0.550837</td>
#       <td>0.543964</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.318300</td>
#       <td>0.709133</td>
#       <td>0.709133</td>
#       <td>0.842101</td>
#       <td>0.638117</td>
#       <td>0.286175</td>
#       <td>0.536239</td>
#       <td>0.529151</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=7506, training_loss=0.544247556361649, metrics={'train_runtime': 1032.3571, 'train_samples_per_second': 29.083, 'train_steps_per_second': 7.271, 'total_flos': 1.2317887451672856e+16, 'train_loss': 0.544247556361649, 'epoch': 6.0})

# %%
trainer.save_model("../../results/modernbert_authentic_multirc_with_reference")

# %% [markdown]
# ## Functionality Test

# %%
from transformers import pipeline

classifier = pipeline(
    task="text-classification",
    model="../../results/modernbert_authentic_multirc",
    tokenizer=model_name_or_path,
    device=0,
)

sample = "Smoking is bad for your health."

classifier(sample)
# Out:
# [{'label': 'LABEL_0', 'score': 1.8023130893707275}]
