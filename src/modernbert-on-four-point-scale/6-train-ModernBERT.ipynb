# %% [markdown]
# # Train ModernBERT on Pseudo-labeled Data
#
# Pseudo-labeled data comes from two sources:
# - MultiRC, pseudo-labeled by GPT5
# - Authentic iTELL data, pseudo-labeled by o3-mini
#
# Humans have labeled a non-overlapping portion of the authentic iTELL data. This will be our held-out test set.

# %%
import os
from pathlib import Path

import numpy as np
import pandas as pd
import torch
import datasets
import optuna
from transformers import (
    Trainer,
    TrainingArguments,
    DataCollatorWithPadding,
    AutoTokenizer,
    AutoModelForSequenceClassification,
    EarlyStoppingCallback,
)
from sklearn import metrics
from scipy import stats

torch.set_float32_matmul_precision("high")
os.environ["TOKENIZERS_PARALLELISM"] = "true"

# %%
model_name_or_path = "answerdotai/ModernBERT-base"
output_dir = "../../results/modernbert-multirc-pseudo-labeled"

# MultiRC With Reference Answer and GPT5 4-point scores:
multirc_path = "../../data/multirc-data-w-gpt5-scores-v3.csv"

# Authentic data from iTELL, scored by the iTELL development team
test_data_path = "../../data/authentic_test_data_v2.csv"

seed = 42

tokenizer = AutoTokenizer.from_pretrained(model_name_or_path)

# %% [markdown]
# ## Construct Dataset

# %%
multirc_df = (
    pd.read_csv(multirc_path)[[
        "split", "passage", "question", "answer", "response", "gpt5_score"
    ]]
    .rename(columns={"gpt5_score": "label"})
    .reset_index(names="id")
)

test_df = (
    pd.read_csv(test_data_path)
    [["chunk_text", "question", "answer", "response", "human_score"]]
    .rename(columns={"human_score": "label", "chunk_text": "passage"})
    .reset_index(names="id")
)

multirc_df
# Out:
#           id  split                                            passage  \
# 0          0  train  The rally took place on October 17, the shooti...
# 1          1  train  The rally took place on October 17, the shooti...
# 2          2  train  The rally took place on October 17, the shooti...
# 3          3  train  The rally took place on October 17, the shooti...
# 4          4  train  The rally took place on October 17, the shooti...
# ...      ...    ...                                                ...
# 32086  32086   test  You have seen your own reflection in a mirror....
# 32087  32087   test  You have seen your own reflection in a mirror....
# 32088  32088   test  You have seen your own reflection in a mirror....
# 32089  32089   test  You have seen your own reflection in a mirror....
# 32090  32090   test  You have seen your own reflection in a mirror....
#
#                                                 question  \
# ...

# %%
dd = datasets.DatasetDict({
    "train": datasets.Dataset.from_pandas(
        multirc_df.query("split == 'train'").drop(columns="split"),
        preserve_index=False
    ),
    "dev": datasets.Dataset.from_pandas(
        multirc_df.query("split == 'dev'").drop(columns="split"),
        preserve_index=False
    ),
    "test": datasets.Dataset.from_pandas(
        multirc_df.query("split == 'test'").drop(columns="split"),
        preserve_index=False
    ),
    "authentic_test": datasets.Dataset.from_pandas(test_df)
})

dd
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'passage', 'question', 'answer', 'response', 'label'],
#         num_rows: 21785
#     })
#     dev: Dataset({
#         features: ['id', 'passage', 'question', 'answer', 'response', 'label'],
#         num_rows: 4770
#     })
#     test: Dataset({
#         features: ['id', 'passage', 'question', 'answer', 'response', 'label'],
#         num_rows: 5536
#     })
#     authentic_test: Dataset({
#         features: ['id', 'passage', 'question', 'answer', 'response', 'label'],
#         num_rows: 490
#     })
# })

# %% [markdown]
# ## Prepare Dataset

# %%
def preprocess_function(example):
    input_str = "\n\n\n".join(
        [
            f"Passage: {example['passage']}",
            f"Question: {example['question']}",
            f"Reference Answer: {example['answer']}",
            f"Student Response: {example['response']}",
        ]
    )
    new_example = tokenizer(input_str)
    return tokenizer(input_str)


dd = dd.map(
    preprocess_function,
    batched=False,
    remove_columns=[
        "id",
        "passage",
        "question",
        "response",
        "answer",
    ],
)

# Convert label column to float type
new_features = dd["train"].features.copy()
new_features["label"] = datasets.Value("float32")
dd = dd.cast(new_features)
dd
# Out:
# ...
# Map:   0%|          | 0/4770 [00:00<?, ? examples/s]

# %% [markdown]
# ## Set Up Training

# %%
def model_init():
    model = AutoModelForSequenceClassification.from_pretrained(
        model_name_or_path,
        num_labels=1,
    )
    return model

# %%
def compute_metrics(eval_pred):
    """
    eval_pred : tuple
        A tuple of (logits, labels) provided by the Hugging Face Trainer.
        - logits: numpy array of shape (n_samples,) for binary classification
        - labels: numpy array of shape (n_samples,)
    """
    preds, labels = eval_pred

    metric_dict = {}

    # Regression metrics
    metric_dict["mse"] = metrics.mean_squared_error(labels, preds)
    metric_dict["rmse"] = metrics.mean_squared_error(labels, preds, squared=False)
    metric_dict["mae"] = metrics.mean_absolute_error(labels, preds)
    metric_dict["r2"] = metrics.r2_score(labels, preds)

    # Classification metrics (round to integers for ordinal ratings)
    preds_int = np.round(preds).astype(int)
    labels_int = np.round(labels).astype(int)

    # Quadratic Weighted Kappa
    metric_dict["qwk"] = metrics.cohen_kappa_score(
        labels_int, preds_int, weights="quadratic"
    )

    # Spearman's r
    metric_dict["spearman"] = stats.spearmanr(labels_int, preds_int).statistic

    return metric_dict

# %%
def hp_space(trial):
    """Define hyperparameter space for Optuna"""
    return {
        "learning_rate": trial.suggest_float("learning_rate", 1e-5, 8e-5, log=True),
        "weight_decay": trial.suggest_float("weight_decay", 1e-6, 5e-6, log=True),
    }

# %%
# Set up base training arguments (without hp search params)
training_args = TrainingArguments(
    output_dir=output_dir,
    bf16=True,
    optim="adamw_torch_fused",
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    logging_dir="../../logs",
    eval_strategy="epoch",
    save_strategy="epoch",
    load_best_model_at_end=True,
    seed=seed,
    log_level="error",
    disable_tqdm=False,
    report_to="none",
    num_train_epochs=8,
    metric_for_best_model="eval_loss",
    greater_is_better=False,
)

data_collator = DataCollatorWithPadding(tokenizer=tokenizer, padding="longest")

trainer = Trainer(
    model_init=model_init,
    args=training_args,
    data_collator=data_collator,
    train_dataset=dd["train"],
    eval_dataset=dd["dev"],
    compute_metrics=compute_metrics,
    callbacks=[EarlyStoppingCallback(early_stopping_patience=2)],  # Stop trial if 2 epochs without improvement
)

# %%
best_trial = trainer.hyperparameter_search(
    hp_space=hp_space,
    backend="optuna",
    n_trials=20,  # Number of trials to run
    direction="minimize",
    sampler=optuna.samplers.TPESampler(seed=seed),
)
print(f"Best trial: {best_trial}")
print(f"Best hyperparameters: {best_trial.hyperparameters}")
# Out:
# [I 2025-10-18 19:59:20,950] A new study created in memory with name: no-name-f12a4449-d237-41fa-944c-451ccf420697
#     <div>
#
#       <progress value='16344' max='21792' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [16344/21792 50:52 < 16:57, 5.35 it/s, Epoch 6/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Mse</th>
#       <th>Rmse</th>
#       <th>Mae</th>
#       <th>R2</th>
#       <th>Qwk</th>
#       <th>Spearman</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.506100</td>
#       <td>0.495766</td>
#       <td>0.495766</td>
#       <td>0.704107</td>
#       <td>0.497960</td>
#       <td>0.501474</td>
#       <td>0.677189</td>
#       <td>0.706904</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.317600</td>
#       <td>0.390251</td>
# ...

# %%
print(f"Best trial: {best_trial}")
print(f"Best hyperparameters: {best_trial.hyperparameters}")
# learning_rate=1.3832442448846103e-05
# weight_decay=1.2853916978930148e-06
# epochs=4

# %%
# Train with best hyperparameters
for param, value in best_trial.hyperparameters.items():
    setattr(trainer.args, param, value)

trainer.train()

# %%
trainer.save_model("../../results/modernbert_multirc_reading_engagement")

# %% [markdown]
# ### Load training args

# %%
torch.load("../../results/modernbert_multirc_reading_engagement/training_args.bin", weights_only=False)
