# %%
import json
import io

from tqdm.auto import tqdm
import pandas as pd
import jinja2
from dotenv import load_dotenv
from openai import OpenAI

import seaborn as sns
import matplotlib.pyplot as plt

load_dotenv("../.env")
client = OpenAI()

# %%
df = pd.read_csv("../../data/itell-question-data-sampled.csv", index_col=0)
df
# Out:
#                                         id  \
# 4139  38f590ee-1964-4a7c-9625-53b53cb8a9f0
# 4124  95784937-f565-4450-bfad-babc2399d667
# 4132  88c0f433-7fdb-48ad-9898-a08d861635e1
# 4120  53c99817-a318-45e5-a918-6b2e7dd4e8d1
# 4128  9f3eeb88-7254-402f-b025-b3c0298e2a64
# ...                                    ...
# 180                                   2257
# 135                                   1515
# 221                                   2458
# 245                                   2794
# 2008                                   232
#
#                                                response  score condition  \
# 4139                                           learning      0       NaN
# 4124                                             answer      0       NaN
# 4132  human observers made live annotations regardin...      0       NaN
# 4120  Recorded data from student while doing help ba...      0       NaN
# 4128                                  analyzing context      0       NaN
# ...                                                 ...    ...       ...
# 180   Slow technological progress, natural disasters...      2    stairs
# 135   Economic conditions before 1870 were sluggish ...      2    stairs
# 221                       economic conditions were slow      2    stairs
# 245   Before 1870, economic conditions were relative...      2    stairs
# 2008  The purpose of a "do . . . while " loop in Jav...      2    stairs
#
#                          user_id  \
# 4139   clu91tykw0002l00fz3o1vfsh
# 4124   cluc0hclp0000ju0flnuywkrr
# 4132   clu7cooq9000kjt0fbxh29vfy
# 4120   clucz38h40005jv0fhc5vjpfp
# 4128   clu8uwkw20000jz0f4yyg6c1d
# ...                          ...
# 180   pkwlvvzebu2ppqvjop66x5hequ
# 135   mx25ylobcck2yg2xkiv4srpfh4
# 221   kwj3wlbqwnfecwceaxe2noulju
# 245   dggh43s5cosnmyxo57zex3cucy
# 2008  c35eotu6a3guavdkekjwe3346i
#
#                                               page_slug  \
# 4139                                          emotional
# 4124                                          emotional
# 4132                                          emotional
# 4120                                          emotional
# 4128                                          emotional
# ...                                                 ...
# 180   7-1-the-relatively-recent-arrival-of-economic-...
# 135   7-1-the-relatively-recent-arrival-of-economic-...
# 221   7-1-the-relatively-recent-arrival-of-economic-...
# 245   7-1-the-relatively-recent-arrival-of-economic-...
# 2008                                2-program-structure
#
#                                              chunk_slug  \
# 4139  01-Affect-Detection-from-Student-Activity-Data...
# 4124  01-Affect-Detection-from-Student-Activity-Data...
# 4132  01-Affect-Detection-from-Student-Activity-Data...
# 4120  01-Affect-Detection-from-Student-Activity-Data...
# 4128  01-Affect-Detection-from-Student-Activity-Data...
# ...                                                 ...
# 180                            learning-objectives-700t
# 135                            learning-objectives-700t
# 221                            learning-objectives-700t
# 245                            learning-objectives-700t
# 2008                            while-and-do-Loops-789t
#
#                             created_at          volume_slug  \
# 4139           2024-04-15 19:57:38.656              cornell
# 4124            2024-05-05 20:29:28.14              cornell
# 4132           2024-04-15 19:03:37.985              cornell
# 4120           2024-03-30 01:56:12.488              cornell
# 4128           2024-05-03 20:56:52.298              cornell
# ...                                ...                  ...
# 180   2024-08-15 22:19:30.781007+00:00             cttc-poe
# 135   2024-08-12 18:03:45.775565+00:00             cttc-poe
# 221   2024-08-15 23:28:39.503359+00:00             cttc-poe
# 245   2024-08-16 20:43:33.145129+00:00             cttc-poe
# 2008      2024-09-01 20:34:24.20905+00  eloquent-javascript
#
#                         volume_title  \
# 4139  Handbook of Learning Analytics
# 4124  Handbook of Learning Analytics
# 4132  Handbook of Learning Analytics
# 4120  Handbook of Learning Analytics
# 4128  Handbook of Learning Analytics
# ...                              ...
# 180     Principles of Macroeconomics
# 135     Principles of Macroeconomics
# 221     Principles of Macroeconomics
# 245     Principles of Macroeconomics
# 2008             Eloquent JavaScript
#
#                                              page_title  \
# 4139                       Emotional Learning Analytics
# 4124                       Emotional Learning Analytics
# 4132                       Emotional Learning Analytics
# 4120                       Emotional Learning Analytics
# 4128                       Emotional Learning Analytics
# ...                                                 ...
# 180   7.1 The Relatively Recent Arrival of Economic ...
# 135   7.1 The Relatively Recent Arrival of Economic ...
# 221   7.1 The Relatively Recent Arrival of Economic ...
# 245   7.1 The Relatively Recent Arrival of Economic ...
# 2008                               2. Program Structure
#
#                                          chunk_header  \
# 4139  0.1 Affect Detection from Student Activity Data
# 4124  0.1 Affect Detection from Student Activity Data
# 4132  0.1 Affect Detection from Student Activity Data
# 4120  0.1 Affect Detection from Student Activity Data
# 4128  0.1 Affect Detection from Student Activity Data
# ...                                               ...
# 180                               learning objectives
# 135                               learning objectives
# 221                               learning objectives
# 245                               learning objectives
# 2008                               while and do Loops
#
#                                              chunk_text  \
# 4139  Affective states cannot be directly measured b...
# 4124  Affective states cannot be directly measured b...
# 4132  Affective states cannot be directly measured b...
# 4120  Affective states cannot be directly measured b...
# 4128  Affective states cannot be directly measured b...
# ...                                                 ...
# 180   Let’s begin with a brief overview of spectacul...
# 135   Let’s begin with a brief overview of spectacul...
# 221   Let’s begin with a brief overview of spectacul...
# 245   Let’s begin with a brief overview of spectacul...
# 2008  Consider a program that outputs all even numbe...
#
#                                                question  \
# 4139  What approach was used to infer affect by anal...
# 4124  What approach was used to infer affect by anal...
# 4132  What approach was used to infer affect by anal...
# 4120  What approach was used to infer affect by anal...
# 4128  What approach was used to infer affect by anal...
# ...                                                 ...
# 180     What were economic conditions like before 1870?
# 135     What were economic conditions like before 1870?
# 221     What were economic conditions like before 1870?
# 245     What were economic conditions like before 1870?
# 2008    What is the purpose of a do loop in JavaScript?
#
#                                                  answer
# 4139  The interaction-based, log-file based, or sens...
# 4124  The interaction-based, log-file based, or sens...
# 4132  The interaction-based, log-file based, or sens...
# 4120  The interaction-based, log-file based, or sens...
# 4128  The interaction-based, log-file based, or sens...
# ...                                                 ...
# 180   Economic conditions before 1870 were marked by...
# 135   Economic conditions before 1870 were marked by...
# 221   Economic conditions before 1870 were marked by...
# 245   Economic conditions before 1870 were marked by...
# 2008  A do loop always executes its body at least on...
#
# [1428 rows x 15 columns]

# %% [markdown]
# ## Data Distribution

# %%
# Set up the plotting area
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Plot score distribution
sns.countplot(x="score", data=df, ax=axs[0], alpha=0.7)
axs[0].set_title("Score Distribution")

# Plot volume distributions
sns.countplot(y="volume_slug", data=df, ax=axs[1], alpha=0.7)
axs[1].set_title("Volume Distribution")
axs[1].set_ylabel("Volume")

# Plot chunk distributions (top N chunks for clarity)
top_chunks = df["chunk_slug"].value_counts().head(10).index
top_chunk_df = df[df["chunk_slug"].isin(top_chunks)]

sns.countplot(y="chunk_slug", data=top_chunk_df, order=top_chunks, ax=axs[2], alpha=0.7)
axs[2].set_title("Chunk Distribution (Top 10)")
axs[2].set_ylabel("Chunk")

plt.tight_layout()
plt.show();
# Out:
# /home/jovyan/conda_envs/openai/lib/python3.11/site-packages/seaborn/categorical.py:1273: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(aggregator, agg_var)
# /home/jovyan/conda_envs/openai/lib/python3.11/site-packages/seaborn/categorical.py:1273: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(aggregator, agg_var)
# /home/jovyan/conda_envs/openai/lib/python3.11/site-packages/seaborn/categorical.py:1273: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(aggregator, agg_var)

# %% [markdown]
# ## Test Prompt

# %%
environment = jinja2.Environment(loader=jinja2.FileSystemLoader("../../prompts/"))
template = environment.get_template("response-score-with-reference-answer.jinja2")

print(template.render(df.sample(1).to_dict(orient="records")[0]))
# Out:
# You are an expert educational assessment evaluator. Your task is to score a student's short answer response based on a reading engagement rubric.
#
# READING ENGAGEMENT RUBRIC:
# Please score the student's response according to the following rubric. Examples for each level of response are provided in response to two example questions.
#
# Example Questions:
# Question 1: "What are some examples of areas in which governments invest to facilitate capital deepening and technology?"
# Question 1 Reference Answer: "Sciencetific Research, Infrastructure, Education, and Special Economic Zones."
#
# Question 2: "When was the Bill of Rights ratified?"
# Question 2 Reference Answer: "In 1791"
#
# Level 4: Expert Reading
# - Characteristics: Student demonstrates strong engagement with the text and full comprehension of the material.
# - Response Quality: Demonstrates a command of the material and ability to manipulate concepts to form cohesive and detailed answers. Responses are correct, but go beyond a level 3 response by providing more details than the question requires or by constructing the response as a complete sentence.
#
# - Example Response to Question 1: "Education, infrastructure, scientific research funding, and special economic zones."
# - Explanation: This response includes several areas of investment that are described in the reading passage, going beyond what is needed to construct a minimally correct answer.
#
# - Example Response to Question 2: "December 15 1791" or "The Bill of Rights was ratified in 1791"
# - Explanation: These responses go beyond the minimal answer of "1791," showing deeper engagement with the question and the reading passage.
#
# Level 3: Proficient Reading
# - Characteristics: Student is engaged with the text and demonstrates comprehension.
# - Response Quality: The response is correct, demonstrating comprehension. Responses at this level provide evidence that the student has read and understood the passage.
#
# - Example Response to Question 1: "Building roads and research."
# - Explanation: This response is correct, utilizing some of the details in the passage.
#
# - Example Response to Question 2: "1791."
# - Explanation: This response is correct, indicating comprehension of the reading passage and the question.
#
# Level 2: Borderline Reading
# - Characteristics: Student may be engaged with the text, but is not demonstrating comprehension.
# - Response Quality: The response is incomplete, only partially accurate, or omits key information that would be necessary to assess comprehension. Typically, responses at this level with use some vocabulary from the passage or provide evidence that the student has at least read the passage superficially.
#
# - Example Response to Question 1: "Healthcare and infrastructure"
# - Explanation: "Healthcare" is not discussed in the reading passage, so this response only includes one relevant detail from the passage, while the question asks for multiple examples.
#
# - Example Response to Question 2: "After the states approved them"
# - Explanation: This response is somewhat accurate, but missing the most relevant detail from the passage. This may indicate poor engagement with the reading passage or disinterest in providing a detailed response to the question.
#
# Level 1: Distracted Reading
# - Characteristics: Student is not engaging with the text, may be distracted, or lacks the background knowledge to understand what they are reading.
# - Response Quality: The response is wholly inaccurate or fails to include any specific details from the passage. Responses at this level provide no indication that the student has read the passage.
#
# - Example Response to Question 1: "The government spends money on things".
# - Explanation: This response does not include any information from the reading passage.
#
# - Example Response to Question 2: "In 1787"
# - Explanation: This response likely confuses the signing of the U.S. Constitution with the ratification of the Bill of Rights. This indicates poor engagement with the reading passage.
#
# SCORING INSTRUCTIONS:
# 1. Carefully analyze the student's response in relation to the reading passage, question, and reference answer.
# 2. Student responses that are correct should receive a minimum reading engagement score of 3, for proficient reading.
# 3. Assign a score of 1, 2, 3, or 4. Your response should be a single digit with no preface, explanation, or elaboration.
#
# READING PASSAGE:
# """Information visualizations is the use of interactive visual representations to amplify cognition (Card, Mackinlay, & Shneiderman, 1999). It typically focuses on abstract data without a straightforward representation in 2-D or 3-D space. Visual analytics puts specific emphasis on building models and visualizing these in order to better understand or refine the models. A very useful goal of information visualization is to rely on human perceptual abilities for pattern discovery (trends, gaps, outliers, clusters). These patterns often become more apparent visually than numerically. As Ware (2004) explains it:
#
#           The human visual system is a pattern seeker of enormous power and subtlety. The eye and the visual cortex of the brain form a massively parallel processor that provides the highest-bandwidth channel into human cognitive centers. At higher levels of processing, perception and cognition are closely interrelated, which is the reason why the words "understanding" and "seeing" are synonymous. (p. xxvi)
#
#           As such, visualization ha the potential to be more precise and revealing than conventional statistical computations (Tufte, 2001).
#
#           Static visualizations (i.e., an image) typically provide answers to a limited number of questions that a user might have about a data set. For example, so-called infographics are often used for storytelling in journalism. However, looking at an evocative visualization often leads to new questions that can only be answered by interacting with the data itself (Few, 2009). Adding dynamic interaction techniques to the visualization, therefore, is often necessary to design meaningful visualization tools that encourage exploratory data analysis.
#
#           Another advantage of visualization is the ability to reveal problems with the data itself; for instance, about the way the data has been collected. Especially in the case of learning analytics, where (semi-) automated trackers often capture traces of learner activities, this advantage is valuable for quality control."""
#
# QUESTION:
# """What is the advantage of relying on human perceptual abilities for pattern discovery in information visualization?"""
#
# REFERENCE ANSWER:
# """Patterns often become more apparent visually than numerically."""
#
# STUDENT RESPONSE:
# """the advantage of using human perceptual abilities for pattern discovery in information visualization is that it can reveal problems with the data and can provide answers to questions that a user may have on the dataset. """

# %% [markdown]
# ## Test Model Response

# %%
sample = df.sample(1)
print("Original Score: ", sample["score"].item())

response = client.chat.completions.create(
    model="gpt-5-2025-08-07",
    messages=[
        {
            "role": "user",
            "content": template.render(sample.to_dict(orient="records")[0]),
        }
    ],
    response_format={  # {"score": "1"}
        "type": "json_schema",
        "json_schema": {
            "name": "cri_score_schema",
            "schema": {
                "type": "object",
                "properties": {
                    "score": {
                        "description": "A single digit from 1-4 representing the score of the student's response",
                        "type": "integer",
                    },
                    "additionalProperties": False,
                },
            },
        },
    },
)

score_dict_string = response.choices[0].message.content
score_dict = json.loads(score_dict_string)
score = score_dict["score"]
print(f"GPT Score: {score}")
# Out:
# Original Score:  1
# GPT Score: 3

# %%
print("Question: ", sample.question.item())
print("Reference answer: ", sample.answer.item())
print("Student Response: ", sample.response.item())
# Out:
# Question:  What factors does economic growth depend on according to the passage?
# Reference answer:  Adherence to the rule of law and protection of property rights and contractual rights by a country’s government.
# Student Response:  Economic growth depends upon the efficacy of legal systems to ensure the ability to make and fulfillment of contracts between producers and consumers.

# %% [markdown]
# # Score data

# %%
def format_request(custom_id, template_inputs, template, model_name="gpt-5-2025-08-07"):
    return {
        "custom_id": custom_id,
        "method": "POST",
        "url": "/v1/chat/completions",
        "body": {
            "model": model_name,
            "messages": [
                {"role": "user", "content": template.render(**template_inputs)}
            ],
            "response_format": {
                "type": "json_schema",
                "json_schema": {
                    "name": "cri_score_schema",
                    "schema": {
                        "type": "object",
                        "properties": {
                            "score": {
                                "description": "A single digit from 1-4 representing the score of the student's response",
                                "type": "integer",
                            },
                            "additionalProperties": False,
                        },
                    },
                },
            },
        },
    }


batch_input = pd.DataFrame(
    [
        format_request(
            f"{row.id}",
            {
                "chunk_text": row.chunk_text,
                "question": row.question,
                "answer": row.answer,
                "response": row.response,
            },
            template,
        )
        for row in df.itertuples()
    ]
)

batch_input.to_json(
    "../../data/itell_cri_batch_input_with_label.jsonl", orient="records", lines=True
)

display(batch_input)
print(batch_input.iloc[0]["body"]["messages"][0]["content"])
# Out:
#                                  custom_id method                   url  \
# 0     38f590ee-1964-4a7c-9625-53b53cb8a9f0   POST  /v1/chat/completions
# 1     95784937-f565-4450-bfad-babc2399d667   POST  /v1/chat/completions
# 2     88c0f433-7fdb-48ad-9898-a08d861635e1   POST  /v1/chat/completions
# 3     53c99817-a318-45e5-a918-6b2e7dd4e8d1   POST  /v1/chat/completions
# 4     9f3eeb88-7254-402f-b025-b3c0298e2a64   POST  /v1/chat/completions
# ...                                    ...    ...                   ...
# 1423                                  2257   POST  /v1/chat/completions
# 1424                                  1515   POST  /v1/chat/completions
# 1425                                  2458   POST  /v1/chat/completions
# 1426                                  2794   POST  /v1/chat/completions
# 1427                                   232   POST  /v1/chat/completions
#
#                                                    body
# 0     {'model': 'gpt-5-2025-08-07', 'messages': [{'r...
# 1     {'model': 'gpt-5-2025-08-07', 'messages': [{'r...
# 2     {'model': 'gpt-5-2025-08-07', 'messages': [{'r...
# 3     {'model': 'gpt-5-2025-08-07', 'messages': [{'r...
# 4     {'model': 'gpt-5-2025-08-07', 'messages': [{'r...
# ...                                                 ...
# 1423  {'model': 'gpt-5-2025-08-07', 'messages': [{'r...
# 1424  {'model': 'gpt-5-2025-08-07', 'messages': [{'r...
# 1425  {'model': 'gpt-5-2025-08-07', 'messages': [{'r...
# 1426  {'model': 'gpt-5-2025-08-07', 'messages': [{'r...
# 1427  {'model': 'gpt-5-2025-08-07', 'messages': [{'r...
#
# [1428 rows x 4 columns]
# You are an expert educational assessment evaluator. Your task is to score a student's short answer response based on a reading engagement rubric.
#
# READING ENGAGEMENT RUBRIC:
# Please score the student's response according to the following rubric. Examples for each level of response are provided in response to two example questions.
#
# Example Questions:
# Question 1: "What are some examples of areas in which governments invest to facilitate capital deepening and technology?"
# Question 1 Reference Answer: "Sciencetific Research, Infrastructure, Education, and Special Economic Zones."
#
# Question 2: "When was the Bill of Rights ratified?"
# Question 2 Reference Answer: "In 1791"
#
# Level 4: Expert Reading
# - Characteristics: Student demonstrates strong engagement with the text and full comprehension of the material.
# - Response Quality: Demonstrates a command of the material and ability to manipulate concepts to form cohesive and detailed answers. Responses are correct, but go beyond a level 3 response by providing more details than the question requires or by constructing the response as a complete sentence.
#
# - Example Response to Question 1: "Education, infrastructure, scientific research funding, and special economic zones."
# - Explanation: This response includes several areas of investment that are described in the reading passage, going beyond what is needed to construct a minimally correct answer.
#
# - Example Response to Question 2: "December 15 1791" or "The Bill of Rights was ratified in 1791"
# - Explanation: These responses go beyond the minimal answer of "1791," showing deeper engagement with the question and the reading passage.
#
# Level 3: Proficient Reading
# - Characteristics: Student is engaged with the text and demonstrates comprehension.
# - Response Quality: The response is correct, demonstrating comprehension. Responses at this level provide evidence that the student has read and understood the passage.
#
# - Example Response to Question 1: "Building roads and research."
# - Explanation: This response is correct, utilizing some of the details in the passage.
#
# - Example Response to Question 2: "1791."
# - Explanation: This response is correct, indicating comprehension of the reading passage and the question.
#
# Level 2: Borderline Reading
# - Characteristics: Student may be engaged with the text, but is not demonstrating comprehension.
# - Response Quality: The response is incomplete, only partially accurate, or omits key information that would be necessary to assess comprehension. Typically, responses at this level with use some vocabulary from the passage or provide evidence that the student has at least read the passage superficially.
#
# - Example Response to Question 1: "Healthcare and infrastructure"
# - Explanation: "Healthcare" is not discussed in the reading passage, so this response only includes one relevant detail from the passage, while the question asks for multiple examples.
#
# - Example Response to Question 2: "After the states approved them"
# - Explanation: This response is somewhat accurate, but missing the most relevant detail from the passage. This may indicate poor engagement with the reading passage or disinterest in providing a detailed response to the question.
#
# Level 1: Distracted Reading
# - Characteristics: Student is not engaging with the text, may be distracted, or lacks the background knowledge to understand what they are reading.
# - Response Quality: The response is wholly inaccurate or fails to include any specific details from the passage. Responses at this level provide no indication that the student has read the passage.
#
# - Example Response to Question 1: "The government spends money on things".
# - Explanation: This response does not include any information from the reading passage.
#
# - Example Response to Question 2: "In 1787"
# - Explanation: This response likely confuses the signing of the U.S. Constitution with the ratification of the Bill of Rights. This indicates poor engagement with the reading passage.
#
# SCORING INSTRUCTIONS:
# 1. Carefully analyze the student's response in relation to the reading passage, question, and reference answer.
# 2. Student responses that are correct should receive a minimum reading engagement score of 3, for proficient reading.
# 3. Assign a score of 1, 2, 3, or 4. Your response should be a single digit with no preface, explanation, or elaboration.
#
# READING PASSAGE:
# """Affective states cannot be directly measured because they are conceptual entities. Because they emerge from environment–person interactions and influence action by modulating cognition, it should be possible to infer affect by analyzing context and learner actions. This approach, referred to as “interaction-based,” “log-file based,” or “sensor-free” affect detection has a decade-long history [1, 16](and was recently reviewed by [7]).
#
# As an example, Pardos, Baker, San Pedro, Gowda, & Gowda [55] developed affect detectors for ASSISTments, an intelligent tutoring system (ITS) for middle- and highschool mathematics [60]. The authors collected training data from 229 students while they used ASSISTments in school computer labs. Human observers recorded affect as students interacted with ASSISTments using the Baker-Rodrigo Observation Method Protocol (BROMP) [52]. According to this protocol, trained observers make live annotations of affect based on observable behavior, including explicit actions towards the software’s interface, interactions with peers and teachers, body movements, gestures, and facial expressions. The observers coded four affective states (boredom, frustration, engaged concentration, and confusion) and two behaviors (going off-task and gaming the system1). Supervised learning techniques were used to discriminate each affective state from other states (e.g., bored versus others) using features extracted from ASSISTments log files (performance on problems, hint requests, response times). Accuracy for detecting affective states ranged from .632 to .678 (measured with the A-prime metric, similar to AUROC) for affect and .802 to .819 for behaviors. The classifier was validated in a manner ensuring generalizability to new students from the same population by ensuring each student’s data appears only in the training or the testing data. Pardos et al. [55] provided preliminary evidence on the predictive validity of their detectors. This was done by applying the detectors on log files from a different set of 1,393 students who interacted with ASSISTments several years earlier. Automatically measured affect and behavior moderately correlated with standardized test scores (0:09 < |r| < 0:45)."""
#
# QUESTION:
# """What approach was used to infer affect by analyzing context and learner actions in the study?"""
#
# REFERENCE ANSWER:
# """The interaction-based, log-file based, or sensor-free affect detection approach was used."""
#
# STUDENT RESPONSE:
# """learning"""

# %%
batch_input_file = client.files.create(
    file=open("../../data/itell_cri_batch_input_with_label.jsonl", "rb"),
    purpose="batch",
)
batch_input_file_id = batch_input_file.id
batch_details = client.batches.create(
    input_file_id=batch_input_file_id,
    endpoint="/v1/chat/completions",
    completion_window="24h",
    metadata={"description": "Pseudo Score iTELL CRI 1"},
)
print(f"batch-id:\n{batch_details.id}\n")
print(batch_details)
# Out:
# batch-id:
# batch_68ebde1608ec8190a5d905f3892a1979
#
# Batch(id='batch_68ebde1608ec8190a5d905f3892a1979', completion_window='24h', created_at=1760288278, endpoint='/v1/chat/completions', input_file_id='file-AkcEhrRr5TcAfAukN6dTnK', object='batch', status='validating', cancelled_at=None, cancelling_at=None, completed_at=None, error_file_id=None, errors=None, expired_at=None, expires_at=1760374678, failed_at=None, finalizing_at=None, in_progress_at=None, metadata={'description': 'Pseudo Score iTELL CRI 1'}, output_file_id=None, request_counts=BatchRequestCounts(completed=0, failed=0, total=0), model=None, usage={'input_tokens': 0, 'output_tokens': 0, 'total_tokens': 0, 'input_tokens_details': {'cached_tokens': 0}, 'output_tokens_details': {'reasoning_tokens': 0}})

# %%
batch = client.batches.retrieve("batch_68ebde1608ec8190a5d905f3892a1979")
print(batch)
output_file_id = batch.output_file_id
print(output_file_id)
# Out:
# Batch(id='batch_68ebde1608ec8190a5d905f3892a1979', completion_window='24h', created_at=1760288278, endpoint='/v1/chat/completions', input_file_id='file-AkcEhrRr5TcAfAukN6dTnK', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1760289602, error_file_id=None, errors=None, expired_at=None, expires_at=1760374678, failed_at=None, finalizing_at=1760289520, in_progress_at=1760288340, metadata={'description': 'Pseudo Score iTELL CRI 1'}, output_file_id='file-Y9BtyJqgUMsJgppxAnd8mk', request_counts=BatchRequestCounts(completed=1428, failed=0, total=1428), model='gpt-5-2025-08-07', usage={'input_tokens': 2064093, 'output_tokens': 1418624, 'total_tokens': 3482717, 'input_tokens_details': {'cached_tokens': 564992}, 'output_tokens_details': {'reasoning_tokens': 1391488}})
# file-Y9BtyJqgUMsJgppxAnd8mk

# %%
file_response = client.files.content("file-Y9BtyJqgUMsJgppxAnd8mk")
results = pd.read_json(io.StringIO(file_response.text), lines=True)
results
# Out:
#                                               id  \
# 0     batch_req_68ebe2f1b5348190b7ac779bbffb8b23
# 1     batch_req_68ebe2f1b3e48190b1bb1b0e6d43adf0
# 2     batch_req_68ebe2f1b09081908e645903f8db9f6d
# 3     batch_req_68ebe2f1b78c81909ff66d60242881c7
# 4     batch_req_68ebe2f1aaf881908d9fc4689e5afe10
# ...                                          ...
# 1423  batch_req_68ebe34197c8819095b96ebe8ad8fd58
# 1424  batch_req_68ebe341a6908190a22259194cbe2ae6
# 1425  batch_req_68ebe341c7c0819091a02b8aceb41c1d
# 1426  batch_req_68ebe341d4a481909e4585f8346fd089
# 1427  batch_req_68ebe341de708190b3b866dc0276fe67
#
#                                  custom_id  \
# 0     38f590ee-1964-4a7c-9625-53b53cb8a9f0
# 1     95784937-f565-4450-bfad-babc2399d667
# 2     88c0f433-7fdb-48ad-9898-a08d861635e1
# 3     53c99817-a318-45e5-a918-6b2e7dd4e8d1
# 4     9f3eeb88-7254-402f-b025-b3c0298e2a64
# ...                                    ...
# 1423                                  2257
# 1424                                  1515
# 1425                                  2458
# 1426                                  2794
# 1427                                   232
#
#                                                response  error
# 0     {'status_code': 200, 'request_id': '1ae8bf919b...    NaN
# 1     {'status_code': 200, 'request_id': '04805be12f...    NaN
# 2     {'status_code': 200, 'request_id': '69831439ee...    NaN
# 3     {'status_code': 200, 'request_id': '3335b05f3b...    NaN
# 4     {'status_code': 200, 'request_id': 'a6a2c6b860...    NaN
# ...                                                 ...    ...
# 1423  {'status_code': 200, 'request_id': '27ab9d6402...    NaN
# 1424  {'status_code': 200, 'request_id': 'eaaf3b22d2...    NaN
# 1425  {'status_code': 200, 'request_id': 'a35dc68b14...    NaN
# 1426  {'status_code': 200, 'request_id': '11b236b3ba...    NaN
# 1427  {'status_code': 200, 'request_id': 'ee39e32b71...    NaN
#
# [1428 rows x 4 columns]

# %%
responses = results.apply(
    lambda x: x["response"]["body"]["choices"][0]["message"]["content"], axis=1
)

scores = [json.loads(resp)["score"] for resp in responses]
print(scores[0])
# Out:
# 2

# %%
df["gpt5_score"] = scores

display(df.sample(3))
df["gpt5_score"].value_counts()
# Out:
#         id                                           response  score  \
# 947   1712  Infrastructure, as well as expanding on educat...      2
# 579   1034  The relationship is that productivity is the m...      2
# 1322  1814  investment in capital deepening should have a ...      0
#
#           condition                     user_id  \
# 947   random_reread  jarh7pbfjblrymn564qmuhjxiu
# 579   random_reread  vvdisksaobob4bzmu2rnihfcju
# 1322         stairs  phxvhvdlxdhvxrt66kjsviuca4
#
#                                        page_slug  \
# 947            7-3-components-of-economic-growth
# 579   7-2-labor-productivity-and-economic-growth
# 1322              7-4-production-in-the-long-run
#
#                                       chunk_slug  \
# 947   A-Healthy-Climate-for-Economic-Growth-711t
# 579             The-New-Economy-Controversy-706t
# 1322         Arguments-Favoring-Convergence-713t
#
#                             created_at volume_slug  \
# 947   2024-08-14 00:19:38.508899+00:00    cttc-poe
# 579   2024-08-09 15:44:01.230212+00:00    cttc-poe
# 1322  2024-08-14 03:47:54.010593+00:00    cttc-poe
#
#                       volume_title  \
# 947   Principles of Macroeconomics
# 579   Principles of Macroeconomics
# 1322  Principles of Macroeconomics
#
#                                       page_title  \
# 947            7.3 Components of Economic Growth
# 579   7.2 Labor Productivity and Economic Growth
# 1322                    7.4 Economic Convergence
#
#                                chunk_header  \
# 947   A Healthy Climate for Economic Growth
# 579           The “New Economy” Controversy
# 1322         Arguments Favoring Convergence
#
#                                              chunk_text  \
# 947   While physical and human capital deepening and...
# 579   In recent years a controversy has been brewing...
# 1322  Several arguments suggest that low-income coun...
#
#                                                question  \
# 947   What are some examples of areas in which gover...
# 579   What is the relationship between productivity ...
# 1322  Why might low-income countries have an advanta...
#
#                                                  answer  gpt5_score
# 947   Education, savings and investment, infrastruct...           3
# 579   Productivity per hour is the most important de...           4
# 1322  Low-income countries could benefit from dimini...           3
# gpt5_score
# 2    503
# 3    486
# 1    222
# 4    217
# Name: count, dtype: int64

# %%
df[["score", "gpt5_score"]].corr(method="spearman")
# Out:
#                score  gpt5_score
# score       1.000000    0.596905
# gpt5_score  0.596905    1.000000

# %%
df.to_csv("../../data/itell-question-data-w-gpt5-scores.csv", index=False)

# %%
df.groupby(["score", "gpt5_score"]).size()
# Out:
# score  gpt5_score
# 0      1             162
#        2             213
#        3              56
#        4               1
# 1      1              50
#        2             189
#        3             134
#        4              50
# 2      1              10
#        2             101
#        3             296
#        4             166
# dtype: int64

# %%
crosstab = pd.crosstab(
    df["gpt5_score"],
    df["score"],
)

sns.heatmap(
    crosstab,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["0", "1", "2"],
    yticklabels=["1", "2", "3", "4"],
)
plt.ylabel("GPT5")
plt.xlabel("BLEURT + MPNet Ensemble")
plt.title("Confusion Matrix")
plt.show()

# %%
crosstab = pd.crosstab(
    df["gpt5_score"] > 2,
    df["score"] > 1,
    normalize="index",
)

sns.heatmap(
    crosstab,
    annot=True,
    fmt=".2f",
    cmap="Blues",
    xticklabels=["Fail", "Pass"],
    yticklabels=["Fail", "Pass"],
)

plt.xlabel("BLEURT + MPNet Ensemble")
plt.ylabel("GPT5")
plt.title("Confusion Matrix (Pass/Fail)")
plt.show()

# %%
pd.crosstab(df["score"] > 0, df["gpt5_score"] > 1, margins=True)
# Out:
# gpt5_score  False  True   All
# score
# False         162   270   432
# True           60   936   996
# All           222  1206  1428

# %% [markdown]
# ## Quick Analysis
#
# It seems that o3 is almost always correct when it scores a response as "1" that was scored as passing by the BLEURT+MPNet ensemble. These are generally responses where the student uses a key phrase from the passage or the question but fails to answer the question accurately.
#
# o3 scores of "2" are tricky. These are generally low-quality, short responses. I think it would be beneficial to consider a "conditional pass" feedback mechanism, where a single "2" score is accepted, but repeated scores of "2" will result in the user being prompted to right full and complete answers that include details from the text.

# %%
with pd.option_context("display.max_colwidth", 0):
    would_fail_with_o3 = df.query("score == 0 & `gpt5_score` == 3").rename(
        columns={
            "question": "Question",
            "answer": "Reference Answer",
            "response": "Student Response",
        }
    )
    display(
        would_fail_with_o3[["Question", "Reference Answer", "Student Response"]].sample(
            10
        )
    )
# Out:
#                                                                                                                           Question  \
# 3376  What is the advantage of combining interaction-based and face-based detection in affect detectors?
# 1868  How is data stored in a computer's world?
# 2083  What is the purpose of a constructor function in JavaScript?
# 1982  What are some examples of characters that can be used in binding names?
# 3330  Why is it important to incorporate emotion into the analysis of learning?
# 3929  Why is evaluation of information visualization systems essential?
# 1322  Why might low-income countries have an advantage in achieving greater worker productivity and economic growth in the future?
# 1941  What is the purpose of comments in programming?
# 2545  Why is it important to consider emotions in learning analytics and educational data mining?
# 562   What is the relationship between productivity growth and average wage levels in an economy?
#
#                                                                                                                                                                    Reference Answer  \
# 3376  They can be applied to almost all cases while maintaining a high level of accuracy.
# 1868  All data is stored as long sequences of bits, which are fundamentally alike and can represent any piece of discrete information.
# 2083  A constructor function is used to create an instance object that derives from the proper prototype and has the properties that instances of the class are supposed to have.
# 1982  Letters, digits (except at the beginning), dollar signs, and underscores.
# 3330  It has the unique potential to advance both the science of learning and the science of emotion.
# 3929  The evaluation of information visualization systems is essential to assess effectiveness, efficiency, usability, and usefulness for teachers and learners.
# 1322  Low-income countries could benefit from diminishing marginal returns, the ability to improve technologies easier, and learn from the experiences of faster-growing countries.
# 1941  Comments are used to convey information to human readers and can be completely ignored by the computer.
# 2545  Attempts to analyze learning without considering emotion will be incomplete, and studying emotions without the methods of LA and EDM will yield shallow insights.
# 562   Productivity per hour is the most important determinant of the average wage level in any economy.
#
#                                                           Student Response
# 3376  less accurate but more all encompassing for a variety of contexts
# 1868  Binary Representation
# 2083  create and initialize a new object
# 1982  catch22, finance_plan, sentinalValue
# 3330  Because learning is not a cold intellectual activity
# 3929  assess impact on learning
# 1322  investment in capital deepening should have a larger marginal effect
# 1941  To make something in the program easier to understand
# 2545  To make attempts to analyze learning more complete
# 562   positive correlation?
