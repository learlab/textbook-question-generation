# %%
import json

from tqdm.auto import tqdm
import pandas as pd
import jinja2
from dotenv import load_dotenv
from openai import OpenAI

import seaborn as sns
import matplotlib.pyplot as plt

load_dotenv("../.env")
client = OpenAI()

# %%
df = pd.read_csv("../../data/itell-question-data-sampled.csv", index_col=0)
df
# Out:
#                                         id  \
# 4139  38f590ee-1964-4a7c-9625-53b53cb8a9f0
# 4124  95784937-f565-4450-bfad-babc2399d667
# 4132  88c0f433-7fdb-48ad-9898-a08d861635e1
# 4120  53c99817-a318-45e5-a918-6b2e7dd4e8d1
# 4128  9f3eeb88-7254-402f-b025-b3c0298e2a64
# ...                                    ...
# 180                                   2257
# 135                                   1515
# 221                                   2458
# 245                                   2794
# 2008                                   232
#
#                                                response  score condition  \
# 4139                                           learning      0       NaN
# 4124                                             answer      0       NaN
# 4132  human observers made live annotations regardin...      0       NaN
# 4120  Recorded data from student while doing help ba...      0       NaN
# 4128                                  analyzing context      0       NaN
# ...                                                 ...    ...       ...
# 180   Slow technological progress, natural disasters...      2    stairs
# 135   Economic conditions before 1870 were sluggish ...      2    stairs
# 221                       economic conditions were slow      2    stairs
# 245   Before 1870, economic conditions were relative...      2    stairs
# 2008  The purpose of a "do . . . while " loop in Jav...      2    stairs
#
#                          user_id  \
# 4139   clu91tykw0002l00fz3o1vfsh
# 4124   cluc0hclp0000ju0flnuywkrr
# 4132   clu7cooq9000kjt0fbxh29vfy
# 4120   clucz38h40005jv0fhc5vjpfp
# 4128   clu8uwkw20000jz0f4yyg6c1d
# ...                          ...
# 180   pkwlvvzebu2ppqvjop66x5hequ
# 135   mx25ylobcck2yg2xkiv4srpfh4
# 221   kwj3wlbqwnfecwceaxe2noulju
# 245   dggh43s5cosnmyxo57zex3cucy
# 2008  c35eotu6a3guavdkekjwe3346i
#
#                                               page_slug  \
# 4139                                          emotional
# 4124                                          emotional
# 4132                                          emotional
# 4120                                          emotional
# 4128                                          emotional
# ...                                                 ...
# 180   7-1-the-relatively-recent-arrival-of-economic-...
# 135   7-1-the-relatively-recent-arrival-of-economic-...
# 221   7-1-the-relatively-recent-arrival-of-economic-...
# 245   7-1-the-relatively-recent-arrival-of-economic-...
# 2008                                2-program-structure
#
#                                              chunk_slug  \
# 4139  01-Affect-Detection-from-Student-Activity-Data...
# 4124  01-Affect-Detection-from-Student-Activity-Data...
# 4132  01-Affect-Detection-from-Student-Activity-Data...
# 4120  01-Affect-Detection-from-Student-Activity-Data...
# 4128  01-Affect-Detection-from-Student-Activity-Data...
# ...                                                 ...
# 180                            learning-objectives-700t
# 135                            learning-objectives-700t
# 221                            learning-objectives-700t
# 245                            learning-objectives-700t
# 2008                            while-and-do-Loops-789t
#
#                             created_at          volume_slug  \
# 4139           2024-04-15 19:57:38.656              cornell
# 4124            2024-05-05 20:29:28.14              cornell
# 4132           2024-04-15 19:03:37.985              cornell
# 4120           2024-03-30 01:56:12.488              cornell
# 4128           2024-05-03 20:56:52.298              cornell
# ...                                ...                  ...
# 180   2024-08-15 22:19:30.781007+00:00             cttc-poe
# 135   2024-08-12 18:03:45.775565+00:00             cttc-poe
# 221   2024-08-15 23:28:39.503359+00:00             cttc-poe
# 245   2024-08-16 20:43:33.145129+00:00             cttc-poe
# 2008      2024-09-01 20:34:24.20905+00  eloquent-javascript
#
#                         volume_title  \
# 4139  Handbook of Learning Analytics
# 4124  Handbook of Learning Analytics
# 4132  Handbook of Learning Analytics
# 4120  Handbook of Learning Analytics
# 4128  Handbook of Learning Analytics
# ...                              ...
# 180     Principles of Macroeconomics
# 135     Principles of Macroeconomics
# 221     Principles of Macroeconomics
# 245     Principles of Macroeconomics
# 2008             Eloquent JavaScript
#
#                                              page_title  \
# 4139                       Emotional Learning Analytics
# 4124                       Emotional Learning Analytics
# 4132                       Emotional Learning Analytics
# 4120                       Emotional Learning Analytics
# 4128                       Emotional Learning Analytics
# ...                                                 ...
# 180   7.1 The Relatively Recent Arrival of Economic ...
# 135   7.1 The Relatively Recent Arrival of Economic ...
# 221   7.1 The Relatively Recent Arrival of Economic ...
# 245   7.1 The Relatively Recent Arrival of Economic ...
# 2008                               2. Program Structure
#
#                                          chunk_header  \
# 4139  0.1 Affect Detection from Student Activity Data
# 4124  0.1 Affect Detection from Student Activity Data
# 4132  0.1 Affect Detection from Student Activity Data
# 4120  0.1 Affect Detection from Student Activity Data
# 4128  0.1 Affect Detection from Student Activity Data
# ...                                               ...
# 180                               learning objectives
# 135                               learning objectives
# 221                               learning objectives
# 245                               learning objectives
# 2008                               while and do Loops
#
#                                              chunk_text  \
# 4139  Affective states cannot be directly measured b...
# 4124  Affective states cannot be directly measured b...
# 4132  Affective states cannot be directly measured b...
# 4120  Affective states cannot be directly measured b...
# 4128  Affective states cannot be directly measured b...
# ...                                                 ...
# 180   Let’s begin with a brief overview of spectacul...
# 135   Let’s begin with a brief overview of spectacul...
# 221   Let’s begin with a brief overview of spectacul...
# 245   Let’s begin with a brief overview of spectacul...
# 2008  Consider a program that outputs all even numbe...
#
#                                                question  \
# 4139  What approach was used to infer affect by anal...
# 4124  What approach was used to infer affect by anal...
# 4132  What approach was used to infer affect by anal...
# 4120  What approach was used to infer affect by anal...
# 4128  What approach was used to infer affect by anal...
# ...                                                 ...
# 180     What were economic conditions like before 1870?
# 135     What were economic conditions like before 1870?
# 221     What were economic conditions like before 1870?
# 245     What were economic conditions like before 1870?
# 2008    What is the purpose of a do loop in JavaScript?
#
#                                                  answer
# 4139  The interaction-based, log-file based, or sens...
# 4124  The interaction-based, log-file based, or sens...
# 4132  The interaction-based, log-file based, or sens...
# 4120  The interaction-based, log-file based, or sens...
# 4128  The interaction-based, log-file based, or sens...
# ...                                                 ...
# 180   Economic conditions before 1870 were marked by...
# 135   Economic conditions before 1870 were marked by...
# 221   Economic conditions before 1870 were marked by...
# 245   Economic conditions before 1870 were marked by...
# 2008  A do loop always executes its body at least on...
#
# [1428 rows x 15 columns]

# %% [markdown]
# ## Data Distribution

# %%
# Set up the plotting area
fig, axs = plt.subplots(1, 3, figsize=(15, 5))

# Plot score distribution
sns.countplot(x='score', data=df, ax=axs[0], alpha=0.7)
axs[0].set_title('Score Distribution')

# Plot volume distributions
sns.countplot(y='volume_slug', data=df, ax=axs[1], alpha=0.7)
axs[1].set_title('Volume Distribution')
axs[1].set_ylabel('Volume')

# Plot chunk distributions (top N chunks for clarity)
top_chunks = df['chunk_slug'].value_counts().head(10).index
top_chunk_df = df[df['chunk_slug'].isin(top_chunks)]

sns.countplot(y='chunk_slug', data=top_chunk_df, order=top_chunks, ax=axs[2], alpha=0.7)
axs[2].set_title('Chunk Distribution (Top 10)')
axs[2].set_ylabel('Chunk')

plt.tight_layout()
plt.show();

# %% [markdown]
# ## Test Prompt

# %%
environment = jinja2.Environment(loader=jinja2.FileSystemLoader("prompts"))
template = environment.get_template("response-score.jinja2")

print(template.render(df.sample(1).to_dict(orient="records")[0]))
# Out:
# You are an expert educational assessment evaluator. Your task is to score a student's short answer response based on a specific rubric.
#
# SCORING RUBRIC:
# Please score the student's response according to the following construct map. Examples for each level of response are provided in response to the following example question and example reference answer:
#
# Example Question: "What are some examples of areas in which governments invest to facilitate capital deepening and technology?"
# Example Reference Answer: "Education, savings and investment, infrastructure, special economic zones, and scientific research."
#
# Level 4: Expert Reading
# - Characteristics: Student demonstrates strong engagement with the text and full comprehension of the material.
# - Response Quality: Demonstrates a command of the material and ability to manipulate concepts to form cohesive and detailed answers.
# - Example of Level 4 Response: "Education, infrastructure, scientific research funding, and special economic zones are all examples of how governments invest to facilitate capital deepening and technology growth."
#
# Level 3: Proficient Reading
# - Characteristics: Student is generally engaged with the text and consistently demonstrates comprehension.
# - Response Quality: Includes accurate or plausible information but lacks the depth or connection between concepts seen at Level 3.
# - Example of Level 3 Response: "Government investments include education and building roads and research. They help make the economy better."
#
# Level 2: Borderline Reading
# - Characteristics: Student may be engaged with the text, but is not demonstrating comprehension.
# - Response Quality: The response is partially correct and includes one or two details from the passage, but omits key information that would be necessary to assess comprehension.
# - Example of Level 2 Response: "Infrastructure"
#
# Level 1: Distracted Reading
# - Characteristics: Student is not engaging with the text, may be distracted, or lacks the background knowledge to understand what they are reading.
# - Response Quality: The response is inaccurate or fails to include any specific details from the passage.
# - Example of Level 1 Response: "Japan" or "The government spends money on things."
#
# SCORING INSTRUCTIONS:
# 1. Carefully analyze the student's response in relation to the passage, question, and reference answer.
# 2. Consider the following factors:
#    - Accuracy of information
#    - Depth of comprehension
#    - Connection between concepts
#    - Overall engagement with the material
# 3. Assign a score of 1, 2, 3, or 4.
#
# READING PASSAGE:
# """Where do learning analytics (LA) and educational data mining (EDM) fit in? On one hand, given the key role of emotions in learning, attempts to analyze learning without considering emotion will be incomplete. On the other hand, given the ambiguity and complexity of emotional phenomena, attempts to study emotions during learning without the methods of LA and EDM will only yield shallow insights. There is a body of work adopting a data-driven analytic approach to study the incidence and influence of emotions on the processes and products of learning. In this chapter, we highlight some of the core, emerging, and future themes in this interdisciplinary research area.
#
# First, a note on terminology. Emotion is related but not equivalent to motivation, attitudes, preferences, physiology, arousal, and a host of other constructs. Emotions are also distinct from moods and affective traits [62]. Emotion is not the same as a feeling. Hunger is a feeling but is not an emotion. There is some contention as to what constitutes an emotion. Anger is certainly an emotion, but what about confusion? Confusion has affective components (feelings of being confused, characteristic facial expressions; [18], but there is debate as to whether it is an emotion [34, 63]. In the remainder of this chapter, we use the more inclusive term affective state rather than the more restrictive term emotion."""
#
# QUESTION:
# """Why is it important to consider emotions in learning analytics and educational data mining?"""
#
# REFERENCE ANSWER:
# """Attempts to analyze learning without considering emotion will be incomplete, and studying emotions without the methods of LA and EDM will yield shallow insights."""
#
# STUDENT RESPONSE:
# """It's related to motivation"""

# %% [markdown]
# ## Test Model Response

# %%
sample = df.sample(1)
print("Original Score: ", sample["score"].item())

response = client.chat.completions.create(
    model="o3-mini-2025-01-31",
    messages=[
        {
            "role": "user", 
            "content": template.render(sample.to_dict(orient="records")[0])
        }
    ],
    response_format={  # {"score": "1"}
        "type": "json_schema",
        "json_schema": {
            "name": "cri_score_schema",
            "schema": {
                "type": "object",
                "properties": {
                    "score": {
                        "description": "A single digit from 1-4 representing the score of the student's response",
                        "type": "integer"
                    },
                    "additionalProperties": False
                }
            }
        }
    }
)

score_dict_string = response.choices[0].message.content
score_dict = json.loads(score_dict_string)
score = score_dict["score"]
print(f"GPT Score: {score}")
# Out:
# Original Score:  1
# GPT Score: 2

# %% [markdown]
# # Score data

# %%
responses = []

for row in tqdm(df.itertuples(), total=len(df)):
    response = client.chat.completions.create(
        model="o3-mini-2025-01-31",
        messages=[{
            "role": "user",
            "content": template.render(
                chunk_text = row.chunk_text,
                question = row.question,
                answer = row.answer,
                response = row.response,
            )
        }],
        response_format={  # {"score": "1"}
            "type": "json_schema",
            "json_schema": {
                "name": "cri_score_schema",
                "schema": {
                    "type": "object",
                    "properties": {
                        "score": {
                            "description": "A single digit from 1-4 representing the score of the student's response",
                            "type": "integer"
                        },
                        "additionalProperties": False
                    }
                }
            }
        }
    )
    responses.append(response)
# Out:
#   0%|          | 0/1428 [00:00<?, ?it/s]

# %%
scores = [
    json.loads(response.choices[0].message.content)["score"]
    for response in responses
]

df["o3_mini_score"] = scores

df.sample(3)
# Out:
#                                         id  \
# 2871  3be7dca7-5d8e-4f70-b7ff-2c421270f74e
# 2150  c47888d9-e96e-49ca-af2b-501f464d1349
# 4077  b498e334-5143-4fd4-a04a-cdab6b187209
#
#                                                response  score condition  \
# 2871  The models were generalizable to different gro...      1       NaN
# 2150  Jurisdictional requirement for cases involving...      0       NaN
# 4077  for who? what data is visualized? what is the ...      1       NaN
#
#                         user_id  \
# 2871  cludd41ph0000jn0ferggc8t0
# 2150  clrca1hcm0000l40fwq1qfdoj
# 4077  clud2gdn0000hjv0fwra9053f
#
#                                               page_slug  \
# 2871                                          emotional
# 2150  the-relationship-between-state-and-federal-cou...
# 4077                                      learning-an-1
#
#                            chunk_slug               created_at  \
# 2871               Core-Themes-2-479t   2024-03-30 02:53:18.51
# 2150                introduction-322t  2024-02-19 17:36:11.401
# 4077  How-to-Get-Started-Chunk-2-532t  2024-03-30 22:53:08.915
#
#                                  volume_slug  \
# 2871                                 cornell
# 2150  business-law-and-the-legal-environment
# 4077                                 cornell
#
#                                 volume_title  \
# 2871          Handbook of Learning Analytics
# 2150  Business Law and the Legal Environment
# 4077          Handbook of Learning Analytics
#
#                                              page_title  \
# 2871                       Emotional Learning Analytics
# 2150   The Relationship between State and Federal Co...
# 4077                       Learning Analytics Dashboard
#
#                     chunk_header  \
# 2871               Core Themes 2
# 2150                introduction
# 4077  How to Get Started Chunk 2
#
#                                              chunk_text  \
# 2871  Further, San Pedro, Baker, Bowers, & Heffernan...
# 2150  Although it is sometimes said that there are t...
# 4077            From these traces, we can define sev...
#
#                                                question  \
# 2871  What was a significant finding in the study by...
# 2150  Why are there so many diversity cases in feder...
# 4077  What type of questions are deliberately listed...
#
#                                                  answer  o3_mini_score
# 2871  Automatically measured affective states were s...              1
# 2150  Defense lawyers believe that there is sometime...              2
# 4077  Questions that start with 'what,' 'when,' 'how...              1

# %%
df[["score", "o3_mini_score"]].corr(method="spearman")
# Out:
#                   score  o3_mini_score
# score          1.000000       0.622661
# o3_mini_score  0.622661       1.000000

# %%
df.to_csv("../../data/itell-question-data-w-o3-scores.csv", index=False)

# %%
df.groupby(["score", "o3_mini_score"]).size()
# Out:
# score  o3_mini_score
# 0      1                235
#        2                181
#        3                 14
#        4                  2
# 1      1                 85
#        2                213
#        3                 84
#        4                 41
# 2      1                 22
#        2                171
#        3                146
#        4                234
# dtype: int64

# %%
crosstab = pd.crosstab(
    df["o3_mini_score"],
    df["score"],
)

sns.heatmap(crosstab, annot=True, fmt="d", cmap="Blues", 
            xticklabels=["0", "1", "2"],
            yticklabels=["1", "2", "3", "4"])
plt.ylabel("o3_mini")
plt.xlabel("BLEURT + MPNet Ensemble")
plt.title("Confusion Matrix")
plt.show()

# %%
crosstab = pd.crosstab(
    df["o3_mini_score"] > 1,
    df["score"] > 0,
    normalize="index",
)

sns.heatmap(crosstab, annot=True, fmt=".2f", cmap="Blues", 
            xticklabels=["Fail", "Pass"],
            yticklabels=["Fail", "Pass"])

plt.xlabel("BLEURT + MPNet Ensemble")
plt.ylabel("o3_mini")
plt.title("Confusion Matrix (Pass/Fail)")
plt.show()

# %%
pd.crosstab(
    df["score"] > 0,
    df["o3_mini_score"] > 1,
    margins=True
)
# Out:
# o3_mini_score  False  True   All
# score
# False            235   197   432
# True             107   889   996
# All              342  1086  1428

# %% [markdown]
# ## Quick Analysis
#
# It seems that o3 is almost always correct when it scores a response as "1" that was scored as passing by the BLEURT+MPNet ensemble. These are generally responses where the student uses a key phrase from the passage or the question but fails to answer the question accurately.
#
# o3 scores of "2" are tricky. These are generally low-quality, short responses. I think it would be beneficial to consider a "conditional pass" feedback mechanism, where a single "2" score is accepted, but repeated scores of "2" will result in the user being prompted to right full and complete answers that include details from the text.

# %%
with pd.option_context('display.max_colwidth', 0):
    would_fail_with_o3 = (
        df
        .query("score == 0 & `o3_mini_score` == 2")
        .rename(columns={
            "question": "Question",
            "answer": "Reference Answer",
            "response": "Student Response",
        })
    )
    display(would_fail_with_o3[["Question", "Reference Answer", "Student Response"]].sample(10))
# Out:
#                                                                                                                     Question  \
# 3281  What is the aim of affect-aware learning technologies like Affective AutoTutor?
# 2475  What are the five primitive cognitive operations that transform information in ways that cannot be further decomposed?
# 3355  Why is it important to incorporate emotion into the analysis of learning?
# 178   What were economic conditions like before 1870?
# 37    What were economic conditions like before 1870?
# 3971  What data should be gathered for input to methods used to generate learning analytics?
# 146   What were economic conditions like before 1870?
# 62    What were economic conditions like before 1870?
# 4087  What type of questions are deliberately listed for both teachers and students in the design process?
# 3775  What are learning analytics designed to do?
#
#                                                                                                                                                                Reference Answer  \
# 3281  The aim is to expand the adaptivity of current learning technologies by responding to what students feel in addition to what they think and do.
# 2475  searching, monitoring, assembling, rehearsing, and translating.
# 3355  It has the unique potential to advance both the science of learning and the science of emotion.
# 178   Economic conditions before 1870 were marked by slow technological progress, natural disasters, and institutions that played a critical role in determining income levels.
# 37    Economic conditions before 1870 were marked by slow technological progress, natural disasters, and institutions that played a critical role in determining income levels.
# 3971  Data that can be used for computations and analysis to predict student progress and performance.
# 146   Economic conditions before 1870 were marked by slow technological progress, natural disasters, and institutions that played a critical role in determining income levels.
# 62    Economic conditions before 1870 were marked by slow technological progress, natural disasters, and institutions that played a critical role in determining income levels.
# 4087  Questions that start with 'what,' 'when,' 'how much,' and 'how often.'
# 3775  Learning analytics are designed to optimize learning and the environments in which it occurs.
#
#                                                                                                                                  Student Response
# 3281  To help students develop mastery on difficult topics
# 2475  SMART
# 3355  they influence thoughts and behavior
# 178   people could not afford as much food
# 37    Low standard of living, Industrial revolution led to high inequalities of nation's GDP.
# 3971  social connections
# 146   Terrible, as many people were barely scrapping the st4andard of living
# 62    Equally bad around the world. Per Capita income levels hovered between $600-800 for nearly everyone (in current international dollar units)
# 4087  how miuch time spent
# 3775  Learning analytics are designed to support SRL
